# %% [markdown]
# # Ejemplo de redis

# %% [markdown]
# ## Importar redis

# %%
import redis

# %% [markdown]
# ## Conexion al server de redis

# %%
r = redis.StrictRedis(
    host='127.0.0.1', 
    port=6379, 
    db=0, 
    password=None, 
    socket_timeout=None,
    connection_pool=None, 
    charset='utf-8', 
    errors='strict', 
    unix_socket_path=None)

# %% [markdown]
# # Seteo de clave valor

# %%
r.set('Moneda','Pesos')
r.get('Moneda')
# Out:
# b'Pesos'

# %% [markdown]
# # Seteo de ciclo de vida de lo almacenado

# %%
r.set('Moneda','Dolar', ex=10)
# Out:
# True

# %% [markdown]
# # Tiepo de vida restante de la data dentro de regis

# %%
r.pttl('Moneda')
# Out:
# 9958

# %% [markdown]
# # Seteo de persistencia

# %%
r.persist('Moneda')
# Out:
# True

# %% [markdown]
# # Mini ejemplo

# %%
import time
r.set('Moneda','Euro', ex=3) # 3 segundos de time to live
t_end = time.time() + 4      # 4 segundos de check
while time.time() < t_end:
    print("Valor=" ,r.get('Moneda'), "Tiempo restante= ", r.pttl('Moneda'))
# Out:
# Valor= b'Euro' Tiempo restante=  2993
# Valor= b'Euro' Tiempo restante=  2987
# Valor= b'Euro' Tiempo restante=  2984
# Valor= b'Euro' Tiempo restante=  2977
# Valor= b'Euro' Tiempo restante=  2973
# Valor= b'Euro' Tiempo restante=  2969
# Valor= b'Euro' Tiempo restante=  2966
# Valor= b'Euro' Tiempo restante=  2961
# Valor= b'Euro' Tiempo restante=  2957
# Valor= b'Euro' Tiempo restante=  2953
# Valor= b'Euro' Tiempo restante=  2950
# Valor= b'Euro' Tiempo restante=  2946
# Valor= b'Euro' Tiempo restante=  2940
# Valor= b'Euro' Tiempo restante=  2936
# Valor= b'Euro' Tiempo restante=  2932
# Valor= b'Euro' Tiempo restante=  2927
# Valor= b'Euro' Tiempo restante=  2922
# Valor= b'Euro' Tiempo restante=  2917
# Valor= b'Euro' Tiempo restante=  2912
# Valor= b'Euro' Tiempo restante=  2907
# Valor= b'Euro' Tiempo restante=  2904
# Valor= b'Euro' Tiempo restante=  2900
# Valor= b'Euro' Tiempo restante=  2896
# Valor= b'Euro' Tiempo restante=  2892
# Valor= b'Euro' Tiempo restante=  2888
# Valor= b'Euro' Tiempo restante=  2884
# Valor= b'Euro' Tiempo restante=  2881
# Valor= b'Euro' Tiempo restante=  2877
# Valor= b'Euro' Tiempo restante=  2874
# Valor= b'Euro' Tiempo restante=  2871
# Valor= b'Euro' Tiempo restante=  2867
# Valor= b'Euro' Tiempo restante=  2863
# Valor= b'Euro' Tiempo restante=  2860
# Valor= b'Euro' Tiempo restante=  2856
# Valor= b'Euro' Tiempo restante=  2853
# Valor= b'Euro' Tiempo restante=  2850
# Valor= b'Euro' Tiempo restante=  2846
# Valor= b'Euro' Tiempo restante=  2843
# Valor= b'Euro' Tiempo restante=  2839
# Valor= b'Euro' Tiempo restante=  2836
# Valor= b'Euro' Tiempo restante=  2832
# Valor= b'Euro' Tiempo restante=  2830
# Valor= b'Euro' Tiempo restante=  2826
# Valor= b'Euro' Tiempo restante=  2823
# Valor= b'Euro' Tiempo restante=  2820
# Valor= b'Euro' Tiempo restante=  2817
# Valor= b'Euro' Tiempo restante=  2813
# Valor= b'Euro' Tiempo restante=  2810
# Valor= b'Euro' Tiempo restante=  2807
# Valor= b'Euro' Tiempo restante=  2803
# Valor= b'Euro' Tiempo restante=  2800
# Valor= b'Euro' Tiempo restante=  2797
# Valor= b'Euro' Tiempo restante=  2794
# Valor= b'Euro' Tiempo restante=  2790
# Valor= b'Euro' Tiempo restante=  2785
# Valor= b'Euro' Tiempo restante=  2782
# Valor= b'Euro' Tiempo restante=  2778
# Valor= b'Euro' Tiempo restante=  2775
# Valor= b'Euro' Tiempo restante=  2771
# Valor= b'Euro' Tiempo restante=  2768
# Valor= b'Euro' Tiempo restante=  2764
# Valor= b'Euro' Tiempo restante=  2761
# Valor= b'Euro' Tiempo restante=  2758
# Valor= b'Euro' Tiempo restante=  2755
# Valor= b'Euro' Tiempo restante=  2751
# Valor= b'Euro' Tiempo restante=  2748
# Valor= b'Euro' Tiempo restante=  2744
# Valor= b'Euro' Tiempo restante=  2741
# Valor= b'Euro' Tiempo restante=  2738
# Valor= b'Euro' Tiempo restante=  2734
# Valor= b'Euro' Tiempo restante=  2731
# Valor= b'Euro' Tiempo restante=  2728
# Valor= b'Euro' Tiempo restante=  2725
# Valor= b'Euro' Tiempo restante=  2721
# Valor= b'Euro' Tiempo restante=  2718
# Valor= b'Euro' Tiempo restante=  2715
# Valor= b'Euro' Tiempo restante=  2711
# Valor= b'Euro' Tiempo restante=  2707
# Valor= b'Euro' Tiempo restante=  2704
# Valor= b'Euro' Tiempo restante=  2700
# Valor= b'Euro' Tiempo restante=  2697
# Valor= b'Euro' Tiempo restante=  2694
# Valor= b'Euro' Tiempo restante=  2690
# Valor= b'Euro' Tiempo restante=  2687
# Valor= b'Euro' Tiempo restante=  2684
# Valor= b'Euro' Tiempo restante=  2681
# Valor= b'Euro' Tiempo restante=  2678
# Valor= b'Euro' Tiempo restante=  2675
# Valor= b'Euro' Tiempo restante=  2672
# Valor= b'Euro' Tiempo restante=  2669
# Valor= b'Euro' Tiempo restante=  2666
# Valor= b'Euro' Tiempo restante=  2663
# Valor= b'Euro' Tiempo restante=  2660
# Valor= b'Euro' Tiempo restante=  2657
# Valor= b'Euro' Tiempo restante=  2654
# Valor= b'Euro' Tiempo restante=  2650
# Valor= b'Euro' Tiempo restante=  2647
# Valor= b'Euro' Tiempo restante=  2643
# Valor= b'Euro' Tiempo restante=  2639
# Valor= b'Euro' Tiempo restante=  2635
# Valor= b'Euro' Tiempo restante=  2630
# Valor= b'Euro' Tiempo restante=  2626
# Valor= b'Euro' Tiempo restante=  2620
# Valor= b'Euro' Tiempo restante=  2614
# Valor= b'Euro' Tiempo restante=  2609
# Valor= b'Euro' Tiempo restante=  2603
# Valor= b'Euro' Tiempo restante=  2598
# Valor= b'Euro' Tiempo restante=  2594
# Valor= b'Euro' Tiempo restante=  2590
# Valor= b'Euro' Tiempo restante=  2586
# Valor= b'Euro' Tiempo restante=  2580
# Valor= b'Euro' Tiempo restante=  2575
# Valor= b'Euro' Tiempo restante=  2570
# Valor= b'Euro' Tiempo restante=  2566
# Valor= b'Euro' Tiempo restante=  2561
# Valor= b'Euro' Tiempo restante=  2556
# Valor= b'Euro' Tiempo restante=  2552
# Valor= b'Euro' Tiempo restante=  2548
# Valor= b'Euro' Tiempo restante=  2543
# Valor= b'Euro' Tiempo restante=  2539
# Valor= b'Euro' Tiempo restante=  2535
# Valor= b'Euro' Tiempo restante=  2531
# Valor= b'Euro' Tiempo restante=  2528
# Valor= b'Euro' Tiempo restante=  2524
# Valor= b'Euro' Tiempo restante=  2521
# Valor= b'Euro' Tiempo restante=  2517
# Valor= b'Euro' Tiempo restante=  2512
# Valor= b'Euro' Tiempo restante=  2508
# Valor= b'Euro' Tiempo restante=  2503
# Valor= b'Euro' Tiempo restante=  2494
# Valor= b'Euro' Tiempo restante=  2490
# Valor= b'Euro' Tiempo restante=  2486
# Valor= b'Euro' Tiempo restante=  2479
# Valor= b'Euro' Tiempo restante=  2474
# Valor= b'Euro' Tiempo restante=  2470
# Valor= b'Euro' Tiempo restante=  2466
# Valor= b'Euro' Tiempo restante=  2461
# Valor= b'Euro' Tiempo restante=  2457
# Valor= b'Euro' Tiempo restante=  2453
# Valor= b'Euro' Tiempo restante=  2450
# Valor= b'Euro' Tiempo restante=  2445
# Valor= b'Euro' Tiempo restante=  2442
# Valor= b'Euro' Tiempo restante=  2439
# Valor= b'Euro' Tiempo restante=  2435
# Valor= b'Euro' Tiempo restante=  2430
# Valor= b'Euro' Tiempo restante=  2427
# Valor= b'Euro' Tiempo restante=  2423
# Valor= b'Euro' Tiempo restante=  2420
# Valor= b'Euro' Tiempo restante=  2417
# Valor= b'Euro' Tiempo restante=  2413
# Valor= b'Euro' Tiempo restante=  2410
# Valor= b'Euro' Tiempo restante=  2407
# Valor= b'Euro' Tiempo restante=  2404
# Valor= b'Euro' Tiempo restante=  2400
# Valor= b'Euro' Tiempo restante=  2396
# Valor= b'Euro' Tiempo restante=  2393
# Valor= b'Euro' Tiempo restante=  2390
# Valor= b'Euro' Tiempo restante=  2387
# Valor= b'Euro' Tiempo restante=  2384
# Valor= b'Euro' Tiempo restante=  2380
# Valor= b'Euro' Tiempo restante=  2376
# Valor= b'Euro' Tiempo restante=  2371
# Valor= b'Euro' Tiempo restante=  2368
# Valor= b'Euro' Tiempo restante=  2364
# Valor= b'Euro' Tiempo restante=  2360
# Valor= b'Euro' Tiempo restante=  2357
# Valor= b'Euro' Tiempo restante=  2354
# Valor= b'Euro' Tiempo restante=  2351
# Valor= b'Euro' Tiempo restante=  2347
# Valor= b'Euro' Tiempo restante=  2344
# Valor= b'Euro' Tiempo restante=  2341
# Valor= b'Euro' Tiempo restante=  2338
# Valor= b'Euro' Tiempo restante=  2335
# Valor= b'Euro' Tiempo restante=  2329
# Valor= b'Euro' Tiempo restante=  2326
# Valor= b'Euro' Tiempo restante=  2323
# Valor= b'Euro' Tiempo restante=  2319
# Valor= b'Euro' Tiempo restante=  2316
# Valor= b'Euro' Tiempo restante=  2312
# Valor= b'Euro' Tiempo restante=  2308
# Valor= b'Euro' Tiempo restante=  2305
# Valor= b'Euro' Tiempo restante=  2301
# Valor= b'Euro' Tiempo restante=  2296
# Valor= b'Euro' Tiempo restante=  2292
# Valor= b'Euro' Tiempo restante=  2287
# Valor= b'Euro' Tiempo restante=  2284
# Valor= b'Euro' Tiempo restante=  2280
# Valor= b'Euro' Tiempo restante=  2277
# Valor= b'Euro' Tiempo restante=  2273
# Valor= b'Euro' Tiempo restante=  2268
# Valor= b'Euro' Tiempo restante=  2264
# Valor= b'Euro' Tiempo restante=  2259
# Valor= b'Euro' Tiempo restante=  2255
# Valor= b'Euro' Tiempo restante=  2252
# Valor= b'Euro' Tiempo restante=  2247
# Valor= b'Euro' Tiempo restante=  2243
# Valor= b'Euro' Tiempo restante=  2239
# Valor= b'Euro' Tiempo restante=  2235
# Valor= b'Euro' Tiempo restante=  2230
# Valor= b'Euro' Tiempo restante=  2226
# Valor= b'Euro' Tiempo restante=  2222
# Valor= b'Euro' Tiempo restante=  2217
# Valor= b'Euro' Tiempo restante=  2213
# Valor= b'Euro' Tiempo restante=  2208
# Valor= b'Euro' Tiempo restante=  2205
# Valor= b'Euro' Tiempo restante=  2201
# Valor= b'Euro' Tiempo restante=  2196
# Valor= b'Euro' Tiempo restante=  2192
# Valor= b'Euro' Tiempo restante=  2186
# Valor= b'Euro' Tiempo restante=  2181
# Valor= b'Euro' Tiempo restante=  2176
# Valor= b'Euro' Tiempo restante=  2173
# Valor= b'Euro' Tiempo restante=  2170
# Valor= b'Euro' Tiempo restante=  2167
# Valor= b'Euro' Tiempo restante=  2163
# Valor= b'Euro' Tiempo restante=  2159
# Valor= b'Euro' Tiempo restante=  2155
# Valor= b'Euro' Tiempo restante=  2152
# Valor= b'Euro' Tiempo restante=  2149
# Valor= b'Euro' Tiempo restante=  2145
# Valor= b'Euro' Tiempo restante=  2141
# Valor= b'Euro' Tiempo restante=  2138
# Valor= b'Euro' Tiempo restante=  2135
# Valor= b'Euro' Tiempo restante=  2130
# Valor= b'Euro' Tiempo restante=  2127
# Valor= b'Euro' Tiempo restante=  2124
# Valor= b'Euro' Tiempo restante=  2121
# Valor= b'Euro' Tiempo restante=  2118
# Valor= b'Euro' Tiempo restante=  2114
# Valor= b'Euro' Tiempo restante=  2110
# Valor= b'Euro' Tiempo restante=  2107
# Valor= b'Euro' Tiempo restante=  2104
# Valor= b'Euro' Tiempo restante=  2101
# Valor= b'Euro' Tiempo restante=  2097
# Valor= b'Euro' Tiempo restante=  2094
# Valor= b'Euro' Tiempo restante=  2091
# Valor= b'Euro' Tiempo restante=  2088
# Valor= b'Euro' Tiempo restante=  2085
# Valor= b'Euro' Tiempo restante=  2082
# Valor= b'Euro' Tiempo restante=  2078
# Valor= b'Euro' Tiempo restante=  2075
# Valor= b'Euro' Tiempo restante=  2072
# Valor= b'Euro' Tiempo restante=  2069
# Valor= b'Euro' Tiempo restante=  2065
# Valor= b'Euro' Tiempo restante=  2062
# Valor= b'Euro' Tiempo restante=  2059
# Valor= b'Euro' Tiempo restante=  2056
# Valor= b'Euro' Tiempo restante=  2053
# Valor= b'Euro' Tiempo restante=  2050
# Valor= b'Euro' Tiempo restante=  2046
# Valor= b'Euro' Tiempo restante=  2043
# Valor= b'Euro' Tiempo restante=  2040
# Valor= b'Euro' Tiempo restante=  2037
# Valor= b'Euro' Tiempo restante=  2034
# Valor= b'Euro' Tiempo restante=  2030
# Valor= b'Euro' Tiempo restante=  2027
# Valor= b'Euro' Tiempo restante=  2024
# Valor= b'Euro' Tiempo restante=  2020
# Valor= b'Euro' Tiempo restante=  2016
# Valor= b'Euro' Tiempo restante=  2013
# Valor= b'Euro' Tiempo restante=  2009
# Valor= b'Euro' Tiempo restante=  2004
# Valor= b'Euro' Tiempo restante=  1999
# Valor= b'Euro' Tiempo restante=  1994
# Valor= b'Euro' Tiempo restante=  1990
# Valor= b'Euro' Tiempo restante=  1985
# Valor= b'Euro' Tiempo restante=  1980
# Valor= b'Euro' Tiempo restante=  1975
# Valor= b'Euro' Tiempo restante=  1971
# Valor= b'Euro' Tiempo restante=  1963
# Valor= b'Euro' Tiempo restante=  1959
# Valor= b'Euro' Tiempo restante=  1955
# Valor= b'Euro' Tiempo restante=  1951
# Valor= b'Euro' Tiempo restante=  1944
# Valor= b'Euro' Tiempo restante=  1939
# Valor= b'Euro' Tiempo restante=  1935
# Valor= b'Euro' Tiempo restante=  1928
# Valor= b'Euro' Tiempo restante=  1924
# Valor= b'Euro' Tiempo restante=  1921
# Valor= b'Euro' Tiempo restante=  1917
# Valor= b'Euro' Tiempo restante=  1913
# Valor= b'Euro' Tiempo restante=  1910
# Valor= b'Euro' Tiempo restante=  1907
# Valor= b'Euro' Tiempo restante=  1903
# Valor= b'Euro' Tiempo restante=  1900
# Valor= b'Euro' Tiempo restante=  1897
# Valor= b'Euro' Tiempo restante=  1895
# Valor= b'Euro' Tiempo restante=  1891
# Valor= b'Euro' Tiempo restante=  1888
# Valor= b'Euro' Tiempo restante=  1885
# Valor= b'Euro' Tiempo restante=  1882
# Valor= b'Euro' Tiempo restante=  1879
# Valor= b'Euro' Tiempo restante=  1875
# Valor= b'Euro' Tiempo restante=  1872
# Valor= b'Euro' Tiempo restante=  1869
# Valor= b'Euro' Tiempo restante=  1866
# Valor= b'Euro' Tiempo restante=  1862
# Valor= b'Euro' Tiempo restante=  1859
# Valor= b'Euro' Tiempo restante=  1855
# Valor= b'Euro' Tiempo restante=  1852
# Valor= b'Euro' Tiempo restante=  1849
# Valor= b'Euro' Tiempo restante=  1846
# Valor= b'Euro' Tiempo restante=  1843
# Valor= b'Euro' Tiempo restante=  1839
# Valor= b'Euro' Tiempo restante=  1837
# Valor= b'Euro' Tiempo restante=  1834
# Valor= b'Euro' Tiempo restante=  1831
# Valor= b'Euro' Tiempo restante=  1827
# Valor= b'Euro' Tiempo restante=  1824
# Valor= b'Euro' Tiempo restante=  1821
# Valor= b'Euro' Tiempo restante=  1817
# Valor= b'Euro' Tiempo restante=  1814
# Valor= b'Euro' Tiempo restante=  1811
# Valor= b'Euro' Tiempo restante=  1808
# Valor= b'Euro' Tiempo restante=  1804
# Valor= b'Euro' Tiempo restante=  1800
# Valor= b'Euro' Tiempo restante=  1797
# Valor= b'Euro' Tiempo restante=  1793
# Valor= b'Euro' Tiempo restante=  1790
# Valor= b'Euro' Tiempo restante=  1787
# Valor= b'Euro' Tiempo restante=  1784
# Valor= b'Euro' Tiempo restante=  1780
# Valor= b'Euro' Tiempo restante=  1776
# Valor= b'Euro' Tiempo restante=  1773
# Valor= b'Euro' Tiempo restante=  1769
# Valor= b'Euro' Tiempo restante=  1766
# Valor= b'Euro' Tiempo restante=  1762
# Valor= b'Euro' Tiempo restante=  1758
# Valor= b'Euro' Tiempo restante=  1754
# Valor= b'Euro' Tiempo restante=  1749
# Valor= b'Euro' Tiempo restante=  1745
# Valor= b'Euro' Tiempo restante=  1742
# Valor= b'Euro' Tiempo restante=  1738
# Valor= b'Euro' Tiempo restante=  1734
# Valor= b'Euro' Tiempo restante=  1731
# Valor= b'Euro' Tiempo restante=  1725
# Valor= b'Euro' Tiempo restante=  1721
# Valor= b'Euro' Tiempo restante=  1717
# Valor= b'Euro' Tiempo restante=  1710
# Valor= b'Euro' Tiempo restante=  1705
# Valor= b'Euro' Tiempo restante=  1701
# Valor= b'Euro' Tiempo restante=  1695
# Valor= b'Euro' Tiempo restante=  1691
# Valor= b'Euro' Tiempo restante=  1687
# Valor= b'Euro' Tiempo restante=  1683
# Valor= b'Euro' Tiempo restante=  1676
# Valor= b'Euro' Tiempo restante=  1672
# Valor= b'Euro' Tiempo restante=  1668
# Valor= b'Euro' Tiempo restante=  1662
# Valor= b'Euro' Tiempo restante=  1658
# Valor= b'Euro' Tiempo restante=  1653
# Valor= b'Euro' Tiempo restante=  1650
# Valor= b'Euro' Tiempo restante=  1643
# Valor= b'Euro' Tiempo restante=  1639
# Valor= b'Euro' Tiempo restante=  1635
# Valor= b'Euro' Tiempo restante=  1630
# Valor= b'Euro' Tiempo restante=  1626
# Valor= b'Euro' Tiempo restante=  1621
# Valor= b'Euro' Tiempo restante=  1611
# Valor= b'Euro' Tiempo restante=  1607
# Valor= b'Euro' Tiempo restante=  1604
# Valor= b'Euro' Tiempo restante=  1600
# Valor= b'Euro' Tiempo restante=  1596
# Valor= b'Euro' Tiempo restante=  1592
# Valor= b'Euro' Tiempo restante=  1588
# Valor= b'Euro' Tiempo restante=  1585
# Valor= b'Euro' Tiempo restante=  1581
# Valor= b'Euro' Tiempo restante=  1577
# Valor= b'Euro' Tiempo restante=  1574
# Valor= b'Euro' Tiempo restante=  1570
# Valor= b'Euro' Tiempo restante=  1566
# Valor= b'Euro' Tiempo restante=  1563
# Valor= b'Euro' Tiempo restante=  1559
# Valor= b'Euro' Tiempo restante=  1556
# Valor= b'Euro' Tiempo restante=  1553
# Valor= b'Euro' Tiempo restante=  1550
# Valor= b'Euro' Tiempo restante=  1546
# Valor= b'Euro' Tiempo restante=  1543
# Valor= b'Euro' Tiempo restante=  1540
# Valor= b'Euro' Tiempo restante=  1537
# Valor= b'Euro' Tiempo restante=  1533
# Valor= b'Euro' Tiempo restante=  1530
# Valor= b'Euro' Tiempo restante=  1527
# Valor= b'Euro' Tiempo restante=  1523
# Valor= b'Euro' Tiempo restante=  1520
# Valor= b'Euro' Tiempo restante=  1517
# Valor= b'Euro' Tiempo restante=  1513
# Valor= b'Euro' Tiempo restante=  1509
# Valor= b'Euro' Tiempo restante=  1505
# Valor= b'Euro' Tiempo restante=  1500
# Valor= b'Euro' Tiempo restante=  1496
# Valor= b'Euro' Tiempo restante=  1492
# Valor= b'Euro' Tiempo restante=  1487
# Valor= b'Euro' Tiempo restante=  1482
# Valor= b'Euro' Tiempo restante=  1476
# Valor= b'Euro' Tiempo restante=  1473
# Valor= b'Euro' Tiempo restante=  1469
# Valor= b'Euro' Tiempo restante=  1464
# Valor= b'Euro' Tiempo restante=  1461
# Valor= b'Euro' Tiempo restante=  1456
# Valor= b'Euro' Tiempo restante=  1453
# Valor= b'Euro' Tiempo restante=  1449
# Valor= b'Euro' Tiempo restante=  1445
# Valor= b'Euro' Tiempo restante=  1442
# Valor= b'Euro' Tiempo restante=  1438
# Valor= b'Euro' Tiempo restante=  1433
# Valor= b'Euro' Tiempo restante=  1429
# Valor= b'Euro' Tiempo restante=  1423
# Valor= b'Euro' Tiempo restante=  1418
# Valor= b'Euro' Tiempo restante=  1414
# Valor= b'Euro' Tiempo restante=  1408
# Valor= b'Euro' Tiempo restante=  1403
# Valor= b'Euro' Tiempo restante=  1396
# Valor= b'Euro' Tiempo restante=  1392
# Valor= b'Euro' Tiempo restante=  1388
# Valor= b'Euro' Tiempo restante=  1384
# Valor= b'Euro' Tiempo restante=  1379
# Valor= b'Euro' Tiempo restante=  1374
# Valor= b'Euro' Tiempo restante=  1370
# Valor= b'Euro' Tiempo restante=  1366
# Valor= b'Euro' Tiempo restante=  1362
# Valor= b'Euro' Tiempo restante=  1356
# Valor= b'Euro' Tiempo restante=  1352
# Valor= b'Euro' Tiempo restante=  1349
# Valor= b'Euro' Tiempo restante=  1344
# Valor= b'Euro' Tiempo restante=  1340
# Valor= b'Euro' Tiempo restante=  1336
# Valor= b'Euro' Tiempo restante=  1288
# Valor= b'Euro' Tiempo restante=  1284
# Valor= b'Euro' Tiempo restante=  1273
# Valor= b'Euro' Tiempo restante=  1270
# Valor= b'Euro' Tiempo restante=  1265
# Valor= b'Euro' Tiempo restante=  1261
# Valor= b'Euro' Tiempo restante=  1257
# Valor= b'Euro' Tiempo restante=  1252
# Valor= b'Euro' Tiempo restante=  1247
# Valor= b'Euro' Tiempo restante=  1243
# Valor= b'Euro' Tiempo restante=  1239
# Valor= b'Euro' Tiempo restante=  1234
# Valor= b'Euro' Tiempo restante=  1229
# Valor= b'Euro' Tiempo restante=  1225
# Valor= b'Euro' Tiempo restante=  1221
# Valor= b'Euro' Tiempo restante=  1217
# Valor= b'Euro' Tiempo restante=  1210
# Valor= b'Euro' Tiempo restante=  1206
# Valor= b'Euro' Tiempo restante=  1202
# Valor= b'Euro' Tiempo restante=  1198
# Valor= b'Euro' Tiempo restante=  1191
# Valor= b'Euro' Tiempo restante=  1186
# Valor= b'Euro' Tiempo restante=  1180
# Valor= b'Euro' Tiempo restante=  1175
# Valor= b'Euro' Tiempo restante=  1172
# Valor= b'Euro' Tiempo restante=  1168
# Valor= b'Euro' Tiempo restante=  1163
# Valor= b'Euro' Tiempo restante=  1159
# Valor= b'Euro' Tiempo restante=  1156
# Valor= b'Euro' Tiempo restante=  1152
# Valor= b'Euro' Tiempo restante=  1148
# Valor= b'Euro' Tiempo restante=  1144
# Valor= b'Euro' Tiempo restante=  1141
# Valor= b'Euro' Tiempo restante=  1138
# Valor= b'Euro' Tiempo restante=  1135
# Valor= b'Euro' Tiempo restante=  1131
# Valor= b'Euro' Tiempo restante=  1128
# Valor= b'Euro' Tiempo restante=  1124
# Valor= b'Euro' Tiempo restante=  1121
# Valor= b'Euro' Tiempo restante=  1118
# Valor= b'Euro' Tiempo restante=  1112
# Valor= b'Euro' Tiempo restante=  1107
# Valor= b'Euro' Tiempo restante=  1104
# Valor= b'Euro' Tiempo restante=  1101
# Valor= b'Euro' Tiempo restante=  1096
# Valor= b'Euro' Tiempo restante=  1093
# Valor= b'Euro' Tiempo restante=  1089
# Valor= b'Euro' Tiempo restante=  1084
# Valor= b'Euro' Tiempo restante=  1079
# Valor= b'Euro' Tiempo restante=  1075
# Valor= b'Euro' Tiempo restante=  1072
# Valor= b'Euro' Tiempo restante=  1068
# Valor= b'Euro' Tiempo restante=  1064
# Valor= b'Euro' Tiempo restante=  1061
# Valor= b'Euro' Tiempo restante=  1058
# Valor= b'Euro' Tiempo restante=  1055
# Valor= b'Euro' Tiempo restante=  1052
# Valor= b'Euro' Tiempo restante=  1049
# Valor= b'Euro' Tiempo restante=  1046
# Valor= b'Euro' Tiempo restante=  1043
# Valor= b'Euro' Tiempo restante=  1039
# Valor= b'Euro' Tiempo restante=  1036
# Valor= b'Euro' Tiempo restante=  1033
# Valor= b'Euro' Tiempo restante=  1029
# Valor= b'Euro' Tiempo restante=  1025
# Valor= b'Euro' Tiempo restante=  1022
# Valor= b'Euro' Tiempo restante=  1018
# Valor= b'Euro' Tiempo restante=  1014
# Valor= b'Euro' Tiempo restante=  1010
# Valor= b'Euro' Tiempo restante=  1004
# Valor= b'Euro' Tiempo restante=  1001
# Valor= b'Euro' Tiempo restante=  996
# Valor= b'Euro' Tiempo restante=  992
# Valor= b'Euro' Tiempo restante=  988
# Valor= b'Euro' Tiempo restante=  984
# Valor= b'Euro' Tiempo restante=  979
# Valor= b'Euro' Tiempo restante=  975
# Valor= b'Euro' Tiempo restante=  971
# Valor= b'Euro' Tiempo restante=  967
# Valor= b'Euro' Tiempo restante=  963
# Valor= b'Euro' Tiempo restante=  959
# Valor= b'Euro' Tiempo restante=  955
# Valor= b'Euro' Tiempo restante=  952
# Valor= b'Euro' Tiempo restante=  949
# Valor= b'Euro' Tiempo restante=  945
# Valor= b'Euro' Tiempo restante=  942
# Valor= b'Euro' Tiempo restante=  939
# Valor= b'Euro' Tiempo restante=  935
# Valor= b'Euro' Tiempo restante=  933
# Valor= b'Euro' Tiempo restante=  929
# Valor= b'Euro' Tiempo restante=  926
# Valor= b'Euro' Tiempo restante=  922
# Valor= b'Euro' Tiempo restante=  919
# Valor= b'Euro' Tiempo restante=  916
# Valor= b'Euro' Tiempo restante=  912
# Valor= b'Euro' Tiempo restante=  910
# Valor= b'Euro' Tiempo restante=  907
# Valor= b'Euro' Tiempo restante=  903
# Valor= b'Euro' Tiempo restante=  900
# Valor= b'Euro' Tiempo restante=  897
# Valor= b'Euro' Tiempo restante=  894
# Valor= b'Euro' Tiempo restante=  891
# Valor= b'Euro' Tiempo restante=  888
# Valor= b'Euro' Tiempo restante=  884
# Valor= b'Euro' Tiempo restante=  880
# Valor= b'Euro' Tiempo restante=  876
# Valor= b'Euro' Tiempo restante=  873
# Valor= b'Euro' Tiempo restante=  870
# Valor= b'Euro' Tiempo restante=  867
# Valor= b'Euro' Tiempo restante=  863
# Valor= b'Euro' Tiempo restante=  860
# Valor= b'Euro' Tiempo restante=  857
# Valor= b'Euro' Tiempo restante=  854
# Valor= b'Euro' Tiempo restante=  851
# Valor= b'Euro' Tiempo restante=  848
# Valor= b'Euro' Tiempo restante=  845
# Valor= b'Euro' Tiempo restante=  842
# Valor= b'Euro' Tiempo restante=  838
# Valor= b'Euro' Tiempo restante=  834
# Valor= b'Euro' Tiempo restante=  830
# Valor= b'Euro' Tiempo restante=  827
# Valor= b'Euro' Tiempo restante=  824
# Valor= b'Euro' Tiempo restante=  821
# Valor= b'Euro' Tiempo restante=  818
# Valor= b'Euro' Tiempo restante=  815
# Valor= b'Euro' Tiempo restante=  812
# Valor= b'Euro' Tiempo restante=  809
# Valor= b'Euro' Tiempo restante=  806
# Valor= b'Euro' Tiempo restante=  802
# Valor= b'Euro' Tiempo restante=  799
# Valor= b'Euro' Tiempo restante=  796
# Valor= b'Euro' Tiempo restante=  793
# Valor= b'Euro' Tiempo restante=  790
# Valor= b'Euro' Tiempo restante=  787
# Valor= b'Euro' Tiempo restante=  783
# Valor= b'Euro' Tiempo restante=  780
# Valor= b'Euro' Tiempo restante=  777
# Valor= b'Euro' Tiempo restante=  774
# Valor= b'Euro' Tiempo restante=  771
# Valor= b'Euro' Tiempo restante=  767
# Valor= b'Euro' Tiempo restante=  764
# Valor= b'Euro' Tiempo restante=  761
# Valor= b'Euro' Tiempo restante=  758
# Valor= b'Euro' Tiempo restante=  755
# Valor= b'Euro' Tiempo restante=  751
# Valor= b'Euro' Tiempo restante=  749
# Valor= b'Euro' Tiempo restante=  745
# Valor= b'Euro' Tiempo restante=  742
# Valor= b'Euro' Tiempo restante=  739
# Valor= b'Euro' Tiempo restante=  736
# Valor= b'Euro' Tiempo restante=  733
# Valor= b'Euro' Tiempo restante=  730
# Valor= b'Euro' Tiempo restante=  727
# Valor= b'Euro' Tiempo restante=  724
# Valor= b'Euro' Tiempo restante=  720
# Valor= b'Euro' Tiempo restante=  717
# Valor= b'Euro' Tiempo restante=  714
# Valor= b'Euro' Tiempo restante=  710
# Valor= b'Euro' Tiempo restante=  705
# Valor= b'Euro' Tiempo restante=  701
# Valor= b'Euro' Tiempo restante=  697
# Valor= b'Euro' Tiempo restante=  694
# Valor= b'Euro' Tiempo restante=  691
# Valor= b'Euro' Tiempo restante=  688
# Valor= b'Euro' Tiempo restante=  685
# Valor= b'Euro' Tiempo restante=  681
# Valor= b'Euro' Tiempo restante=  678
# Valor= b'Euro' Tiempo restante=  675
# Valor= b'Euro' Tiempo restante=  672
# Valor= b'Euro' Tiempo restante=  668
# Valor= b'Euro' Tiempo restante=  663
# Valor= b'Euro' Tiempo restante=  658
# Valor= b'Euro' Tiempo restante=  654
# Valor= b'Euro' Tiempo restante=  648
# Valor= b'Euro' Tiempo restante=  644
# Valor= b'Euro' Tiempo restante=  639
# Valor= b'Euro' Tiempo restante=  634
# Valor= b'Euro' Tiempo restante=  627
# Valor= b'Euro' Tiempo restante=  621
# Valor= b'Euro' Tiempo restante=  616
# Valor= b'Euro' Tiempo restante=  611
# Valor= b'Euro' Tiempo restante=  607
# Valor= b'Euro' Tiempo restante=  602
# Valor= b'Euro' Tiempo restante=  596
# Valor= b'Euro' Tiempo restante=  591
# Valor= b'Euro' Tiempo restante=  586
# Valor= b'Euro' Tiempo restante=  581
# Valor= b'Euro' Tiempo restante=  576
# Valor= b'Euro' Tiempo restante=  571
# Valor= b'Euro' Tiempo restante=  566
# Valor= b'Euro' Tiempo restante=  561
# Valor= b'Euro' Tiempo restante=  557
# Valor= b'Euro' Tiempo restante=  553
# Valor= b'Euro' Tiempo restante=  549
# Valor= b'Euro' Tiempo restante=  545
# Valor= b'Euro' Tiempo restante=  539
# Valor= b'Euro' Tiempo restante=  535
# Valor= b'Euro' Tiempo restante=  531
# Valor= b'Euro' Tiempo restante=  525
# Valor= b'Euro' Tiempo restante=  521
# Valor= b'Euro' Tiempo restante=  517
# Valor= b'Euro' Tiempo restante=  510
# Valor= b'Euro' Tiempo restante=  506
# Valor= b'Euro' Tiempo restante=  502
# Valor= b'Euro' Tiempo restante=  497
# Valor= b'Euro' Tiempo restante=  493
# Valor= b'Euro' Tiempo restante=  490
# Valor= b'Euro' Tiempo restante=  487
# Valor= b'Euro' Tiempo restante=  484
# Valor= b'Euro' Tiempo restante=  481
# Valor= b'Euro' Tiempo restante=  478
# Valor= b'Euro' Tiempo restante=  475
# Valor= b'Euro' Tiempo restante=  472
# Valor= b'Euro' Tiempo restante=  468
# Valor= b'Euro' Tiempo restante=  465
# Valor= b'Euro' Tiempo restante=  462
# Valor= b'Euro' Tiempo restante=  459
# Valor= b'Euro' Tiempo restante=  455
# Valor= b'Euro' Tiempo restante=  452
# Valor= b'Euro' Tiempo restante=  449
# Valor= b'Euro' Tiempo restante=  445
# Valor= b'Euro' Tiempo restante=  442
# Valor= b'Euro' Tiempo restante=  439
# Valor= b'Euro' Tiempo restante=  436
# Valor= b'Euro' Tiempo restante=  432
# Valor= b'Euro' Tiempo restante=  429
# Valor= b'Euro' Tiempo restante=  425
# Valor= b'Euro' Tiempo restante=  422
# Valor= b'Euro' Tiempo restante=  419
# Valor= b'Euro' Tiempo restante=  415
# Valor= b'Euro' Tiempo restante=  412
# Valor= b'Euro' Tiempo restante=  408
# Valor= b'Euro' Tiempo restante=  405
# Valor= b'Euro' Tiempo restante=  403
# Valor= b'Euro' Tiempo restante=  399
# Valor= b'Euro' Tiempo restante=  396
# Valor= b'Euro' Tiempo restante=  393
# Valor= b'Euro' Tiempo restante=  389
# Valor= b'Euro' Tiempo restante=  386
# Valor= b'Euro' Tiempo restante=  383
# Valor= b'Euro' Tiempo restante=  379
# Valor= b'Euro' Tiempo restante=  376
# Valor= b'Euro' Tiempo restante=  373
# Valor= b'Euro' Tiempo restante=  370
# Valor= b'Euro' Tiempo restante=  367
# Valor= b'Euro' Tiempo restante=  363
# Valor= b'Euro' Tiempo restante=  360
# Valor= b'Euro' Tiempo restante=  356
# Valor= b'Euro' Tiempo restante=  353
# Valor= b'Euro' Tiempo restante=  350
# Valor= b'Euro' Tiempo restante=  347
# Valor= b'Euro' Tiempo restante=  343
# Valor= b'Euro' Tiempo restante=  340
# Valor= b'Euro' Tiempo restante=  337
# Valor= b'Euro' Tiempo restante=  334
# Valor= b'Euro' Tiempo restante=  332
# Valor= b'Euro' Tiempo restante=  328
# Valor= b'Euro' Tiempo restante=  326
# Valor= b'Euro' Tiempo restante=  323
# Valor= b'Euro' Tiempo restante=  319
# Valor= b'Euro' Tiempo restante=  316
# Valor= b'Euro' Tiempo restante=  313
# Valor= b'Euro' Tiempo restante=  309
# Valor= b'Euro' Tiempo restante=  305
# Valor= b'Euro' Tiempo restante=  302
# Valor= b'Euro' Tiempo restante=  299
# Valor= b'Euro' Tiempo restante=  296
# Valor= b'Euro' Tiempo restante=  293
# Valor= b'Euro' Tiempo restante=  290
# Valor= b'Euro' Tiempo restante=  287
# Valor= b'Euro' Tiempo restante=  284
# Valor= b'Euro' Tiempo restante=  280
# Valor= b'Euro' Tiempo restante=  277
# Valor= b'Euro' Tiempo restante=  274
# Valor= b'Euro' Tiempo restante=  271
# Valor= b'Euro' Tiempo restante=  268
# Valor= b'Euro' Tiempo restante=  265
# Valor= b'Euro' Tiempo restante=  262
# Valor= b'Euro' Tiempo restante=  259
# Valor= b'Euro' Tiempo restante=  256
# Valor= b'Euro' Tiempo restante=  253
# Valor= b'Euro' Tiempo restante=  249
# Valor= b'Euro' Tiempo restante=  247
# Valor= b'Euro' Tiempo restante=  244
# Valor= b'Euro' Tiempo restante=  241
# Valor= b'Euro' Tiempo restante=  238
# Valor= b'Euro' Tiempo restante=  234
# Valor= b'Euro' Tiempo restante=  229
# Valor= b'Euro' Tiempo restante=  225
# Valor= b'Euro' Tiempo restante=  221
# Valor= b'Euro' Tiempo restante=  217
# Valor= b'Euro' Tiempo restante=  214
# Valor= b'Euro' Tiempo restante=  211
# Valor= b'Euro' Tiempo restante=  208
# Valor= b'Euro' Tiempo restante=  205
# Valor= b'Euro' Tiempo restante=  202
# Valor= b'Euro' Tiempo restante=  199
# Valor= b'Euro' Tiempo restante=  196
# Valor= b'Euro' Tiempo restante=  193
# Valor= b'Euro' Tiempo restante=  189
# Valor= b'Euro' Tiempo restante=  186
# Valor= b'Euro' Tiempo restante=  183
# Valor= b'Euro' Tiempo restante=  180
# Valor= b'Euro' Tiempo restante=  177
# Valor= b'Euro' Tiempo restante=  174
# Valor= b'Euro' Tiempo restante=  170
# Valor= b'Euro' Tiempo restante=  167
# Valor= b'Euro' Tiempo restante=  164
# Valor= b'Euro' Tiempo restante=  160
# Valor= b'Euro' Tiempo restante=  157
# Valor= b'Euro' Tiempo restante=  154
# Valor= b'Euro' Tiempo restante=  151
# Valor= b'Euro' Tiempo restante=  147
# Valor= b'Euro' Tiempo restante=  144
# Valor= b'Euro' Tiempo restante=  141
# Valor= b'Euro' Tiempo restante=  138
# Valor= b'Euro' Tiempo restante=  134
# Valor= b'Euro' Tiempo restante=  131
# Valor= b'Euro' Tiempo restante=  128
# Valor= b'Euro' Tiempo restante=  125
# Valor= b'Euro' Tiempo restante=  122
# Valor= b'Euro' Tiempo restante=  119
# Valor= b'Euro' Tiempo restante=  116
# Valor= b'Euro' Tiempo restante=  112
# Valor= b'Euro' Tiempo restante=  109
# Valor= b'Euro' Tiempo restante=  106
# Valor= b'Euro' Tiempo restante=  102
# Valor= b'Euro' Tiempo restante=  99
# Valor= b'Euro' Tiempo restante=  96
# Valor= b'Euro' Tiempo restante=  93
# Valor= b'Euro' Tiempo restante=  89
# Valor= b'Euro' Tiempo restante=  86
# Valor= b'Euro' Tiempo restante=  82
# Valor= b'Euro' Tiempo restante=  79
# Valor= b'Euro' Tiempo restante=  76
# Valor= b'Euro' Tiempo restante=  73
# Valor= b'Euro' Tiempo restante=  70
# Valor= b'Euro' Tiempo restante=  67
# Valor= b'Euro' Tiempo restante=  63
# Valor= b'Euro' Tiempo restante=  60
# Valor= b'Euro' Tiempo restante=  58
# Valor= b'Euro' Tiempo restante=  55
# Valor= b'Euro' Tiempo restante=  52
# Valor= b'Euro' Tiempo restante=  49
# Valor= b'Euro' Tiempo restante=  46
# Valor= b'Euro' Tiempo restante=  43
# Valor= b'Euro' Tiempo restante=  40
# Valor= b'Euro' Tiempo restante=  37
# Valor= b'Euro' Tiempo restante=  34
# Valor= b'Euro' Tiempo restante=  31
# Valor= b'Euro' Tiempo restante=  28
# Valor= b'Euro' Tiempo restante=  25
# Valor= b'Euro' Tiempo restante=  22
# Valor= b'Euro' Tiempo restante=  19
# Valor= b'Euro' Tiempo restante=  16
# Valor= b'Euro' Tiempo restante=  13
# Valor= b'Euro' Tiempo restante=  10
# Valor= b'Euro' Tiempo restante=  6
# Valor= b'Euro' Tiempo restante=  3
# Valor= b'Euro' Tiempo restante=  0
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2

# %% [markdown]
# # Mini ejemplo 2

# %%
r.zadd('vehiculo', {'Auto' : 1})
r.zadd('vehiculo', {'Moto' : 2})
vehiculo = r.zrange('vehiculo', 0, -1, desc=False, withscores=True)
print(vehiculo)
# Out:
# [(b'Auto', 1.0), (b'Moto', 2.0)]

# %%
# Redis ordenamiento

judadores = 'Jugadores'
r.zadd(judadores, {'Ronaldo' : 100})
r.zadd(judadores, {'Messi' : 99})
r.zadd(judadores, {'Aguero' : 85})
r.zadd(judadores, {'Neymar' : 90})
r.zadd(judadores, {'Salah' : 89})

print("Cardinalidad:")
print(r.zcard(judadores))

print()
print("Cantidad de jugadores con rating entre 90-100:")
print(r.zcount(judadores, 90, 100))

print()
print("Cantidad de jugadores con rating entre 0-89:")
print(r.zcount(judadores, 0, 89))

print()
print("Buscar un valor:")
elementValue = "Messi"
print("Valor '{}' es ".format(elementValue), r.zscore(judadores, "Messi"))

print()
print("Ordenamiento de valores:")
print(r.zrangebyscore(judadores, min=0, max=100, withscores = True))

print()
print("Ordenamiento de valores reverso:")
print(r.zrevrangebyscore(judadores, min=0, max=100, withscores = True))
# Out:
# Cardinalidad:
# 5
#
# Cantidad de jugadores con rating entre 90-100:
# 3
#
# Cantidad de jugadores con rating entre 0-89:
# 2
#
# Buscar un valor:
# Valor 'Messi' es  99.0
#
# Ordenamiento de valores:
# [(b'Aguero', 85.0), (b'Salah', 89.0), (b'Neymar', 90.0), (b'Messi', 99.0), (b'Ronaldo', 100.0)]
#
# Ordenamiento de valores reverso:
# [(b'Ronaldo', 100.0), (b'Messi', 99.0), (b'Neymar', 90.0), (b'Salah', 89.0), (b'Aguero', 85.0)]

# %% [markdown]
# # Mini ejemplo 3

# %%
equipos = "Equipos"

r.zadd(equipos, {'Real Madrid': "1"})
r.zadd(equipos, {'Barcelona': "5"})
r.zadd(equipos, {'Juventus': "2"})
r.zadd(equipos, {'PSG': "3"})
r.zadd(equipos, {'Manchester United': "4"})
r.zadd(equipos, {'Milan': "5"})


print("Valores:")
print(r.zrange(equipos, 0, -1, desc=True, withscores=True))

print("Eliminar items:")
print(r.zrem(equipos, "Barcelona", "PSG"))

 
print("Eliminar items con valores:")
print(r.zremrangebyscore(equipos, 2, 5))

print("Visualizar items restantes:")
print(r.zrevrange(equipos, 0, -1, withscores=True))
# Out:
# Valores:
# [(b'Milan', 5.0), (b'Barcelona', 5.0), (b'Manchester United', 4.0), (b'PSG', 3.0), (b'Juventus', 2.0), (b'Real Madrid', 1.0)]
# Eliminar items:
# 2
# Eliminar items con valores:
# 3
# Visualizar items restantes:
# [(b'Real Madrid', 1.0)]

# %% [markdown]
# # Hash ejemplo 1

# %%
hash_value = 'redis_hash'
r.hset(hash_value, 1, "Uno")
r.hset(hash_value, 2, "Dos")
r.hset(hash_value, 3, "Tres")

print("Vaor para la clave 3")
print(r.hget(hash_value, 3))

 
print("Claves en redis hash:");
print(r.hkeys(hash_value))

print("Valores en redis hash:");
print(r.hvals(hash_value))


print("Claves y valores en redis hash:")
print(r.hgetall(hash_value))
# Out:
# Vaor para la clave 3
# b'Tres'
# Claves en redis hash:
# [b'1', b'2', b'3']
# Valores en redis hash:
# [b'Uno', b'Dos', b'Tres']
# Claves y valores en redis hash:
# {b'1': b'Uno', b'2': b'Dos', b'3': b'Tres'}

# %% [markdown]
# # Hash ejemplo 2

# %%
hash_value = "Cafes"
r.hset(hash_value, 1, "Corto")
r.hset(hash_value, 2, "Doble")
r.hset(hash_value, 3, "Capuchino")
r.hset(hash_value, 4, "Latte")

print(r.hgetall(hash_value))

r.hdel(hash_value, 1)
 
print(r.hgetall(hash_value))
# Out:
# {b'2': b'Doble', b'3': b'Capuchino', b'4': b'Latte', b'1': b'Corto'}
# {b'2': b'Doble', b'3': b'Capuchino', b'4': b'Latte'}

# %% [markdown]
# # Hash ejemplo 3

# %%
hash_value = "Libros"
r.hmset(hash_value,  {1:"Harry Potter y la piedra filosofal", 2:"Harry Potter y la cámara secreta"})

key = 1
print("La clave {} existe:".format(key))
print(r.hexists(hash_value, key)) # Verifico si la clave existe

print("Antes de la eliminación:")
print(r.hgetall(hash_value))

r.hdel(hash_value, key) # Eliminación de la clave

print("Despues de la eliminación de la clave:")
print(r.hgetall(hash_value))
# Out:
# La clave 1 existe:
# True
# Antes de la eliminación:
# {b'2': b'Harry Potter y la c\xc3\xa1mara secreta', b'1': b'Harry Potter y la piedra filosofal'}
# Despues de la eliminación de la clave:
# {b'2': b'Harry Potter y la c\xc3\xa1mara secreta'}
# <ipython-input-16-dd68a12009ed>:2: DeprecationWarning: Redis.hmset() is deprecated. Use Redis.hset() instead.
#   r.hmset(hash_value,  {1:"Harry Potter y la piedra filosofal", 2:"Harry Potter y la cámara secreta"})

# %% [markdown]
# # Ejemplo listas 1

# %%
# Agregar valores a la lista 
# lpush = head list
r.lpush('Paises', "Argentina")
r.lpush('Paises', "Chile")

# Agregar multiples valores a la lista
r.lpush('Paises', "Brasil", "Uruguay")

# Imprimir valores de la lista y liberarlos
while(r.llen('Paises')!=0):
    print(r.lpop('Paises'))
# Out:
# b'Uruguay'
# b'Brasil'
# b'Chile'
# b'Argentina'

# %% [markdown]
# # Ejemplo listas 2

# %%
# Agregar valores a la lista 
# rpush = tail list
paises = "Paises"
r.rpush(paises, "Italia")
r.rpush(paises, "Portugal")
r.rpush(paises, "Alemania")
r.rpush(paises, "Francia")
r.rpush(paises, "Austria")

# Agregar multiples valores a la lista
r.rpush(paises, "Grecia", "Inglaterra")

# Imprimir valores de la lista y liberarlos
while(r.llen(paises)!=0):
    print(r.rpop(paises))
# Out:
# b'Inglaterra'
# b'Grecia'
# b'Austria'
# b'Francia'
# b'Alemania'
# b'Portugal'
# b'Italia'

# %% [markdown]
# # Ejemplo listas 3

# %%
# Lista con todos ceros
lista = "numeros"
r.lpush(lista, 0,0,0,0,0)


print("Lista sin cambios:")
for i in range(0, r.llen(lista)):
    print(r.lindex(lista, i))


# Modificando lista
for i in range(0, r.llen(lista)):
    r.lset(lista, i, i*2)

 
print("Lista modificada:")
for i in range(0, r.llen(lista)):
    print(r.lindex(lista, i))


print("Longuitud de la lista antes de liberarlos:")
print(r.llen(lista)) 

# Liberando la lista
for i in range(0, r.llen(lista)):
    r.lpop(lista)


print("Longuitud de la lista despues de liberarlos:")
print(r.llen(lista))
# Out:
# Lista sin cambios:
# b'0'
# b'0'
# b'0'
# b'0'
# b'0'
# Lista modificada:
# b'0'
# b'2'
# b'4'
# b'6'
# b'8'
# Longuitud de la lista antes de liberarlos:
# 5
# Longuitud de la lista despues de liberarlos:
# 0
