# %% [markdown]
# # Ejemplo de redis

# %% [markdown]
# ## Importar redis

# %%
import redis

# %% [markdown]
# ## Conexion al server de redis

# %%
r = redis.StrictRedis(
    host='127.0.0.1', 
    port=6379, 
    db=0, 
    password=None, 
    socket_timeout=None,
    connection_pool=None, 
    charset='utf-8', 
    errors='strict', 
    unix_socket_path=None)

# %% [markdown]
# # Seteo de clave valor

# %%
r.set('Moneda','Pesos')
r.get('Moneda')
# Out:
# b'Pesos'

# %% [markdown]
# # Seteo de ciclo de vida de lo almacenado

# %%
r.set('Moneda','Dolar', ex=10)
# Out:
# True

# %% [markdown]
# # Tiepo de vida restante de la data dentro de regis

# %%
r.pttl('Moneda')
# Out:
# 9966

# %% [markdown]
# # Seteo de persistencia

# %%
r.persist('Moneda')
# Out:
# True

# %% [markdown]
# # Mini ejemplo

# %%
import time
r.set('Moneda','Euro', ex=3) # 3 segundos de time to live
t_end = time.time() + 4      # 4 segundos de check
while time.time() < t_end:
    print("Valor=" ,r.get('Moneda'), "Tiempo restante= ", r.pttl('Moneda'))
# Out:
# Valor= b'Euro' Tiempo restante=  2992
# Valor= b'Euro' Tiempo restante=  2987
# Valor= b'Euro' Tiempo restante=  2981
# Valor= b'Euro' Tiempo restante=  2976
# Valor= b'Euro' Tiempo restante=  2971
# Valor= b'Euro' Tiempo restante=  2964
# Valor= b'Euro' Tiempo restante=  2959
# Valor= b'Euro' Tiempo restante=  2955
# Valor= b'Euro' Tiempo restante=  2951
# Valor= b'Euro' Tiempo restante=  2947
# Valor= b'Euro' Tiempo restante=  2942
# Valor= b'Euro' Tiempo restante=  2938
# Valor= b'Euro' Tiempo restante=  2935
# Valor= b'Euro' Tiempo restante=  2930
# Valor= b'Euro' Tiempo restante=  2926
# Valor= b'Euro' Tiempo restante=  2922
# Valor= b'Euro' Tiempo restante=  2919
# Valor= b'Euro' Tiempo restante=  2914
# Valor= b'Euro' Tiempo restante=  2911
# Valor= b'Euro' Tiempo restante=  2908
# Valor= b'Euro' Tiempo restante=  2905
# Valor= b'Euro' Tiempo restante=  2901
# Valor= b'Euro' Tiempo restante=  2897
# Valor= b'Euro' Tiempo restante=  2891
# Valor= b'Euro' Tiempo restante=  2888
# Valor= b'Euro' Tiempo restante=  2884
# Valor= b'Euro' Tiempo restante=  2881
# Valor= b'Euro' Tiempo restante=  2877
# Valor= b'Euro' Tiempo restante=  2874
# Valor= b'Euro' Tiempo restante=  2871
# Valor= b'Euro' Tiempo restante=  2867
# Valor= b'Euro' Tiempo restante=  2864
# Valor= b'Euro' Tiempo restante=  2860
# Valor= b'Euro' Tiempo restante=  2857
# Valor= b'Euro' Tiempo restante=  2853
# Valor= b'Euro' Tiempo restante=  2850
# Valor= b'Euro' Tiempo restante=  2847
# Valor= b'Euro' Tiempo restante=  2844
# Valor= b'Euro' Tiempo restante=  2841
# Valor= b'Euro' Tiempo restante=  2837
# Valor= b'Euro' Tiempo restante=  2834
# Valor= b'Euro' Tiempo restante=  2831
# Valor= b'Euro' Tiempo restante=  2828
# Valor= b'Euro' Tiempo restante=  2824
# Valor= b'Euro' Tiempo restante=  2822
# Valor= b'Euro' Tiempo restante=  2818
# Valor= b'Euro' Tiempo restante=  2815
# Valor= b'Euro' Tiempo restante=  2811
# Valor= b'Euro' Tiempo restante=  2808
# Valor= b'Euro' Tiempo restante=  2805
# Valor= b'Euro' Tiempo restante=  2802
# Valor= b'Euro' Tiempo restante=  2799
# Valor= b'Euro' Tiempo restante=  2795
# Valor= b'Euro' Tiempo restante=  2791
# Valor= b'Euro' Tiempo restante=  2787
# Valor= b'Euro' Tiempo restante=  2782
# Valor= b'Euro' Tiempo restante=  2777
# Valor= b'Euro' Tiempo restante=  2773
# Valor= b'Euro' Tiempo restante=  2768
# Valor= b'Euro' Tiempo restante=  2763
# Valor= b'Euro' Tiempo restante=  2758
# Valor= b'Euro' Tiempo restante=  2754
# Valor= b'Euro' Tiempo restante=  2749
# Valor= b'Euro' Tiempo restante=  2743
# Valor= b'Euro' Tiempo restante=  2738
# Valor= b'Euro' Tiempo restante=  2734
# Valor= b'Euro' Tiempo restante=  2729
# Valor= b'Euro' Tiempo restante=  2724
# Valor= b'Euro' Tiempo restante=  2720
# Valor= b'Euro' Tiempo restante=  2717
# Valor= b'Euro' Tiempo restante=  2713
# Valor= b'Euro' Tiempo restante=  2709
# Valor= b'Euro' Tiempo restante=  2705
# Valor= b'Euro' Tiempo restante=  2702
# Valor= b'Euro' Tiempo restante=  2698
# Valor= b'Euro' Tiempo restante=  2694
# Valor= b'Euro' Tiempo restante=  2691
# Valor= b'Euro' Tiempo restante=  2687
# Valor= b'Euro' Tiempo restante=  2684
# Valor= b'Euro' Tiempo restante=  2680
# Valor= b'Euro' Tiempo restante=  2677
# Valor= b'Euro' Tiempo restante=  2674
# Valor= b'Euro' Tiempo restante=  2670
# Valor= b'Euro' Tiempo restante=  2667
# Valor= b'Euro' Tiempo restante=  2663
# Valor= b'Euro' Tiempo restante=  2660
# Valor= b'Euro' Tiempo restante=  2656
# Valor= b'Euro' Tiempo restante=  2653
# Valor= b'Euro' Tiempo restante=  2650
# Valor= b'Euro' Tiempo restante=  2646
# Valor= b'Euro' Tiempo restante=  2642
# Valor= b'Euro' Tiempo restante=  2639
# Valor= b'Euro' Tiempo restante=  2635
# Valor= b'Euro' Tiempo restante=  2631
# Valor= b'Euro' Tiempo restante=  2627
# Valor= b'Euro' Tiempo restante=  2623
# Valor= b'Euro' Tiempo restante=  2619
# Valor= b'Euro' Tiempo restante=  2617
# Valor= b'Euro' Tiempo restante=  2611
# Valor= b'Euro' Tiempo restante=  2606
# Valor= b'Euro' Tiempo restante=  2603
# Valor= b'Euro' Tiempo restante=  2597
# Valor= b'Euro' Tiempo restante=  2593
# Valor= b'Euro' Tiempo restante=  2588
# Valor= b'Euro' Tiempo restante=  2583
# Valor= b'Euro' Tiempo restante=  2577
# Valor= b'Euro' Tiempo restante=  2573
# Valor= b'Euro' Tiempo restante=  2570
# Valor= b'Euro' Tiempo restante=  2565
# Valor= b'Euro' Tiempo restante=  2560
# Valor= b'Euro' Tiempo restante=  2556
# Valor= b'Euro' Tiempo restante=  2552
# Valor= b'Euro' Tiempo restante=  2549
# Valor= b'Euro' Tiempo restante=  2545
# Valor= b'Euro' Tiempo restante=  2540
# Valor= b'Euro' Tiempo restante=  2537
# Valor= b'Euro' Tiempo restante=  2533
# Valor= b'Euro' Tiempo restante=  2529
# Valor= b'Euro' Tiempo restante=  2526
# Valor= b'Euro' Tiempo restante=  2523
# Valor= b'Euro' Tiempo restante=  2519
# Valor= b'Euro' Tiempo restante=  2516
# Valor= b'Euro' Tiempo restante=  2513
# Valor= b'Euro' Tiempo restante=  2509
# Valor= b'Euro' Tiempo restante=  2506
# Valor= b'Euro' Tiempo restante=  2503
# Valor= b'Euro' Tiempo restante=  2500
# Valor= b'Euro' Tiempo restante=  2496
# Valor= b'Euro' Tiempo restante=  2492
# Valor= b'Euro' Tiempo restante=  2489
# Valor= b'Euro' Tiempo restante=  2485
# Valor= b'Euro' Tiempo restante=  2482
# Valor= b'Euro' Tiempo restante=  2479
# Valor= b'Euro' Tiempo restante=  2475
# Valor= b'Euro' Tiempo restante=  2472
# Valor= b'Euro' Tiempo restante=  2469
# Valor= b'Euro' Tiempo restante=  2465
# Valor= b'Euro' Tiempo restante=  2461
# Valor= b'Euro' Tiempo restante=  2458
# Valor= b'Euro' Tiempo restante=  2455
# Valor= b'Euro' Tiempo restante=  2452
# Valor= b'Euro' Tiempo restante=  2449
# Valor= b'Euro' Tiempo restante=  2446
# Valor= b'Euro' Tiempo restante=  2443
# Valor= b'Euro' Tiempo restante=  2440
# Valor= b'Euro' Tiempo restante=  2437
# Valor= b'Euro' Tiempo restante=  2433
# Valor= b'Euro' Tiempo restante=  2430
# Valor= b'Euro' Tiempo restante=  2427
# Valor= b'Euro' Tiempo restante=  2424
# Valor= b'Euro' Tiempo restante=  2421
# Valor= b'Euro' Tiempo restante=  2417
# Valor= b'Euro' Tiempo restante=  2415
# Valor= b'Euro' Tiempo restante=  2411
# Valor= b'Euro' Tiempo restante=  2408
# Valor= b'Euro' Tiempo restante=  2404
# Valor= b'Euro' Tiempo restante=  2401
# Valor= b'Euro' Tiempo restante=  2397
# Valor= b'Euro' Tiempo restante=  2394
# Valor= b'Euro' Tiempo restante=  2391
# Valor= b'Euro' Tiempo restante=  2388
# Valor= b'Euro' Tiempo restante=  2383
# Valor= b'Euro' Tiempo restante=  2380
# Valor= b'Euro' Tiempo restante=  2375
# Valor= b'Euro' Tiempo restante=  2371
# Valor= b'Euro' Tiempo restante=  2366
# Valor= b'Euro' Tiempo restante=  2360
# Valor= b'Euro' Tiempo restante=  2354
# Valor= b'Euro' Tiempo restante=  2350
# Valor= b'Euro' Tiempo restante=  2343
# Valor= b'Euro' Tiempo restante=  2339
# Valor= b'Euro' Tiempo restante=  2334
# Valor= b'Euro' Tiempo restante=  2326
# Valor= b'Euro' Tiempo restante=  2322
# Valor= b'Euro' Tiempo restante=  2317
# Valor= b'Euro' Tiempo restante=  2310
# Valor= b'Euro' Tiempo restante=  2305
# Valor= b'Euro' Tiempo restante=  2300
# Valor= b'Euro' Tiempo restante=  2291
# Valor= b'Euro' Tiempo restante=  2287
# Valor= b'Euro' Tiempo restante=  2283
# Valor= b'Euro' Tiempo restante=  2277
# Valor= b'Euro' Tiempo restante=  2271
# Valor= b'Euro' Tiempo restante=  2266
# Valor= b'Euro' Tiempo restante=  2257
# Valor= b'Euro' Tiempo restante=  2253
# Valor= b'Euro' Tiempo restante=  2250
# Valor= b'Euro' Tiempo restante=  2246
# Valor= b'Euro' Tiempo restante=  2242
# Valor= b'Euro' Tiempo restante=  2237
# Valor= b'Euro' Tiempo restante=  2232
# Valor= b'Euro' Tiempo restante=  2227
# Valor= b'Euro' Tiempo restante=  2223
# Valor= b'Euro' Tiempo restante=  2219
# Valor= b'Euro' Tiempo restante=  2214
# Valor= b'Euro' Tiempo restante=  2210
# Valor= b'Euro' Tiempo restante=  2206
# Valor= b'Euro' Tiempo restante=  2202
# Valor= b'Euro' Tiempo restante=  2198
# Valor= b'Euro' Tiempo restante=  2194
# Valor= b'Euro' Tiempo restante=  2191
# Valor= b'Euro' Tiempo restante=  2185
# Valor= b'Euro' Tiempo restante=  2179
# Valor= b'Euro' Tiempo restante=  2174
# Valor= b'Euro' Tiempo restante=  2168
# Valor= b'Euro' Tiempo restante=  2164
# Valor= b'Euro' Tiempo restante=  2159
# Valor= b'Euro' Tiempo restante=  2155
# Valor= b'Euro' Tiempo restante=  2151
# Valor= b'Euro' Tiempo restante=  2147
# Valor= b'Euro' Tiempo restante=  2144
# Valor= b'Euro' Tiempo restante=  2140
# Valor= b'Euro' Tiempo restante=  2137
# Valor= b'Euro' Tiempo restante=  2135
# Valor= b'Euro' Tiempo restante=  2131
# Valor= b'Euro' Tiempo restante=  2127
# Valor= b'Euro' Tiempo restante=  2124
# Valor= b'Euro' Tiempo restante=  2121
# Valor= b'Euro' Tiempo restante=  2117
# Valor= b'Euro' Tiempo restante=  2114
# Valor= b'Euro' Tiempo restante=  2110
# Valor= b'Euro' Tiempo restante=  2107
# Valor= b'Euro' Tiempo restante=  2104
# Valor= b'Euro' Tiempo restante=  2100
# Valor= b'Euro' Tiempo restante=  2098
# Valor= b'Euro' Tiempo restante=  2094
# Valor= b'Euro' Tiempo restante=  2091
# Valor= b'Euro' Tiempo restante=  2087
# Valor= b'Euro' Tiempo restante=  2083
# Valor= b'Euro' Tiempo restante=  2079
# Valor= b'Euro' Tiempo restante=  2076
# Valor= b'Euro' Tiempo restante=  2072
# Valor= b'Euro' Tiempo restante=  2068
# Valor= b'Euro' Tiempo restante=  2064
# Valor= b'Euro' Tiempo restante=  2061
# Valor= b'Euro' Tiempo restante=  2058
# Valor= b'Euro' Tiempo restante=  2054
# Valor= b'Euro' Tiempo restante=  2051
# Valor= b'Euro' Tiempo restante=  2047
# Valor= b'Euro' Tiempo restante=  2044
# Valor= b'Euro' Tiempo restante=  2041
# Valor= b'Euro' Tiempo restante=  2038
# Valor= b'Euro' Tiempo restante=  2035
# Valor= b'Euro' Tiempo restante=  2031
# Valor= b'Euro' Tiempo restante=  2028
# Valor= b'Euro' Tiempo restante=  2024
# Valor= b'Euro' Tiempo restante=  2021
# Valor= b'Euro' Tiempo restante=  2017
# Valor= b'Euro' Tiempo restante=  2013
# Valor= b'Euro' Tiempo restante=  2010
# Valor= b'Euro' Tiempo restante=  2006
# Valor= b'Euro' Tiempo restante=  2000
# Valor= b'Euro' Tiempo restante=  1996
# Valor= b'Euro' Tiempo restante=  1992
# Valor= b'Euro' Tiempo restante=  1988
# Valor= b'Euro' Tiempo restante=  1985
# Valor= b'Euro' Tiempo restante=  1980
# Valor= b'Euro' Tiempo restante=  1975
# Valor= b'Euro' Tiempo restante=  1968
# Valor= b'Euro' Tiempo restante=  1962
# Valor= b'Euro' Tiempo restante=  1957
# Valor= b'Euro' Tiempo restante=  1952
# Valor= b'Euro' Tiempo restante=  1944
# Valor= b'Euro' Tiempo restante=  1940
# Valor= b'Euro' Tiempo restante=  1932
# Valor= b'Euro' Tiempo restante=  1926
# Valor= b'Euro' Tiempo restante=  1922
# Valor= b'Euro' Tiempo restante=  1917
# Valor= b'Euro' Tiempo restante=  1911
# Valor= b'Euro' Tiempo restante=  1906
# Valor= b'Euro' Tiempo restante=  1901
# Valor= b'Euro' Tiempo restante=  1895
# Valor= b'Euro' Tiempo restante=  1890
# Valor= b'Euro' Tiempo restante=  1887
# Valor= b'Euro' Tiempo restante=  1883
# Valor= b'Euro' Tiempo restante=  1879
# Valor= b'Euro' Tiempo restante=  1875
# Valor= b'Euro' Tiempo restante=  1872
# Valor= b'Euro' Tiempo restante=  1869
# Valor= b'Euro' Tiempo restante=  1865
# Valor= b'Euro' Tiempo restante=  1861
# Valor= b'Euro' Tiempo restante=  1858
# Valor= b'Euro' Tiempo restante=  1855
# Valor= b'Euro' Tiempo restante=  1851
# Valor= b'Euro' Tiempo restante=  1847
# Valor= b'Euro' Tiempo restante=  1844
# Valor= b'Euro' Tiempo restante=  1841
# Valor= b'Euro' Tiempo restante=  1837
# Valor= b'Euro' Tiempo restante=  1834
# Valor= b'Euro' Tiempo restante=  1831
# Valor= b'Euro' Tiempo restante=  1827
# Valor= b'Euro' Tiempo restante=  1824
# Valor= b'Euro' Tiempo restante=  1821
# Valor= b'Euro' Tiempo restante=  1818
# Valor= b'Euro' Tiempo restante=  1814
# Valor= b'Euro' Tiempo restante=  1811
# Valor= b'Euro' Tiempo restante=  1808
# Valor= b'Euro' Tiempo restante=  1804
# Valor= b'Euro' Tiempo restante=  1800
# Valor= b'Euro' Tiempo restante=  1797
# Valor= b'Euro' Tiempo restante=  1793
# Valor= b'Euro' Tiempo restante=  1790
# Valor= b'Euro' Tiempo restante=  1787
# Valor= b'Euro' Tiempo restante=  1784
# Valor= b'Euro' Tiempo restante=  1781
# Valor= b'Euro' Tiempo restante=  1778
# Valor= b'Euro' Tiempo restante=  1774
# Valor= b'Euro' Tiempo restante=  1771
# Valor= b'Euro' Tiempo restante=  1767
# Valor= b'Euro' Tiempo restante=  1763
# Valor= b'Euro' Tiempo restante=  1760
# Valor= b'Euro' Tiempo restante=  1757
# Valor= b'Euro' Tiempo restante=  1753
# Valor= b'Euro' Tiempo restante=  1751
# Valor= b'Euro' Tiempo restante=  1747
# Valor= b'Euro' Tiempo restante=  1744
# Valor= b'Euro' Tiempo restante=  1741
# Valor= b'Euro' Tiempo restante=  1738
# Valor= b'Euro' Tiempo restante=  1735
# Valor= b'Euro' Tiempo restante=  1731
# Valor= b'Euro' Tiempo restante=  1728
# Valor= b'Euro' Tiempo restante=  1725
# Valor= b'Euro' Tiempo restante=  1722
# Valor= b'Euro' Tiempo restante=  1719
# Valor= b'Euro' Tiempo restante=  1715
# Valor= b'Euro' Tiempo restante=  1712
# Valor= b'Euro' Tiempo restante=  1709
# Valor= b'Euro' Tiempo restante=  1706
# Valor= b'Euro' Tiempo restante=  1703
# Valor= b'Euro' Tiempo restante=  1699
# Valor= b'Euro' Tiempo restante=  1696
# Valor= b'Euro' Tiempo restante=  1693
# Valor= b'Euro' Tiempo restante=  1690
# Valor= b'Euro' Tiempo restante=  1686
# Valor= b'Euro' Tiempo restante=  1683
# Valor= b'Euro' Tiempo restante=  1680
# Valor= b'Euro' Tiempo restante=  1678
# Valor= b'Euro' Tiempo restante=  1672
# Valor= b'Euro' Tiempo restante=  1667
# Valor= b'Euro' Tiempo restante=  1664
# Valor= b'Euro' Tiempo restante=  1661
# Valor= b'Euro' Tiempo restante=  1658
# Valor= b'Euro' Tiempo restante=  1654
# Valor= b'Euro' Tiempo restante=  1651
# Valor= b'Euro' Tiempo restante=  1647
# Valor= b'Euro' Tiempo restante=  1644
# Valor= b'Euro' Tiempo restante=  1641
# Valor= b'Euro' Tiempo restante=  1637
# Valor= b'Euro' Tiempo restante=  1634
# Valor= b'Euro' Tiempo restante=  1631
# Valor= b'Euro' Tiempo restante=  1627
# Valor= b'Euro' Tiempo restante=  1624
# Valor= b'Euro' Tiempo restante=  1621
# Valor= b'Euro' Tiempo restante=  1617
# Valor= b'Euro' Tiempo restante=  1614
# Valor= b'Euro' Tiempo restante=  1610
# Valor= b'Euro' Tiempo restante=  1607
# Valor= b'Euro' Tiempo restante=  1604
# Valor= b'Euro' Tiempo restante=  1601
# Valor= b'Euro' Tiempo restante=  1597
# Valor= b'Euro' Tiempo restante=  1593
# Valor= b'Euro' Tiempo restante=  1590
# Valor= b'Euro' Tiempo restante=  1586
# Valor= b'Euro' Tiempo restante=  1582
# Valor= b'Euro' Tiempo restante=  1577
# Valor= b'Euro' Tiempo restante=  1571
# Valor= b'Euro' Tiempo restante=  1565
# Valor= b'Euro' Tiempo restante=  1560
# Valor= b'Euro' Tiempo restante=  1556
# Valor= b'Euro' Tiempo restante=  1552
# Valor= b'Euro' Tiempo restante=  1545
# Valor= b'Euro' Tiempo restante=  1540
# Valor= b'Euro' Tiempo restante=  1535
# Valor= b'Euro' Tiempo restante=  1529
# Valor= b'Euro' Tiempo restante=  1525
# Valor= b'Euro' Tiempo restante=  1519
# Valor= b'Euro' Tiempo restante=  1513
# Valor= b'Euro' Tiempo restante=  1508
# Valor= b'Euro' Tiempo restante=  1503
# Valor= b'Euro' Tiempo restante=  1499
# Valor= b'Euro' Tiempo restante=  1492
# Valor= b'Euro' Tiempo restante=  1488
# Valor= b'Euro' Tiempo restante=  1483
# Valor= b'Euro' Tiempo restante=  1477
# Valor= b'Euro' Tiempo restante=  1473
# Valor= b'Euro' Tiempo restante=  1470
# Valor= b'Euro' Tiempo restante=  1466
# Valor= b'Euro' Tiempo restante=  1459
# Valor= b'Euro' Tiempo restante=  1455
# Valor= b'Euro' Tiempo restante=  1451
# Valor= b'Euro' Tiempo restante=  1445
# Valor= b'Euro' Tiempo restante=  1440
# Valor= b'Euro' Tiempo restante=  1436
# Valor= b'Euro' Tiempo restante=  1431
# Valor= b'Euro' Tiempo restante=  1425
# Valor= b'Euro' Tiempo restante=  1422
# Valor= b'Euro' Tiempo restante=  1418
# Valor= b'Euro' Tiempo restante=  1414
# Valor= b'Euro' Tiempo restante=  1409
# Valor= b'Euro' Tiempo restante=  1406
# Valor= b'Euro' Tiempo restante=  1403
# Valor= b'Euro' Tiempo restante=  1398
# Valor= b'Euro' Tiempo restante=  1395
# Valor= b'Euro' Tiempo restante=  1391
# Valor= b'Euro' Tiempo restante=  1388
# Valor= b'Euro' Tiempo restante=  1384
# Valor= b'Euro' Tiempo restante=  1380
# Valor= b'Euro' Tiempo restante=  1377
# Valor= b'Euro' Tiempo restante=  1373
# Valor= b'Euro' Tiempo restante=  1369
# Valor= b'Euro' Tiempo restante=  1366
# Valor= b'Euro' Tiempo restante=  1361
# Valor= b'Euro' Tiempo restante=  1358
# Valor= b'Euro' Tiempo restante=  1354
# Valor= b'Euro' Tiempo restante=  1350
# Valor= b'Euro' Tiempo restante=  1346
# Valor= b'Euro' Tiempo restante=  1343
# Valor= b'Euro' Tiempo restante=  1339
# Valor= b'Euro' Tiempo restante=  1335
# Valor= b'Euro' Tiempo restante=  1332
# Valor= b'Euro' Tiempo restante=  1329
# Valor= b'Euro' Tiempo restante=  1326
# Valor= b'Euro' Tiempo restante=  1323
# Valor= b'Euro' Tiempo restante=  1320
# Valor= b'Euro' Tiempo restante=  1316
# Valor= b'Euro' Tiempo restante=  1312
# Valor= b'Euro' Tiempo restante=  1310
# Valor= b'Euro' Tiempo restante=  1307
# Valor= b'Euro' Tiempo restante=  1303
# Valor= b'Euro' Tiempo restante=  1301
# Valor= b'Euro' Tiempo restante=  1297
# Valor= b'Euro' Tiempo restante=  1294
# Valor= b'Euro' Tiempo restante=  1290
# Valor= b'Euro' Tiempo restante=  1287
# Valor= b'Euro' Tiempo restante=  1283
# Valor= b'Euro' Tiempo restante=  1280
# Valor= b'Euro' Tiempo restante=  1276
# Valor= b'Euro' Tiempo restante=  1273
# Valor= b'Euro' Tiempo restante=  1269
# Valor= b'Euro' Tiempo restante=  1266
# Valor= b'Euro' Tiempo restante=  1262
# Valor= b'Euro' Tiempo restante=  1259
# Valor= b'Euro' Tiempo restante=  1255
# Valor= b'Euro' Tiempo restante=  1252
# Valor= b'Euro' Tiempo restante=  1249
# Valor= b'Euro' Tiempo restante=  1246
# Valor= b'Euro' Tiempo restante=  1242
# Valor= b'Euro' Tiempo restante=  1239
# Valor= b'Euro' Tiempo restante=  1235
# Valor= b'Euro' Tiempo restante=  1232
# Valor= b'Euro' Tiempo restante=  1228
# Valor= b'Euro' Tiempo restante=  1224
# Valor= b'Euro' Tiempo restante=  1220
# Valor= b'Euro' Tiempo restante=  1215
# Valor= b'Euro' Tiempo restante=  1210
# Valor= b'Euro' Tiempo restante=  1206
# Valor= b'Euro' Tiempo restante=  1201
# Valor= b'Euro' Tiempo restante=  1197
# Valor= b'Euro' Tiempo restante=  1193
# Valor= b'Euro' Tiempo restante=  1188
# Valor= b'Euro' Tiempo restante=  1182
# Valor= b'Euro' Tiempo restante=  1177
# Valor= b'Euro' Tiempo restante=  1172
# Valor= b'Euro' Tiempo restante=  1168
# Valor= b'Euro' Tiempo restante=  1160
# Valor= b'Euro' Tiempo restante=  1155
# Valor= b'Euro' Tiempo restante=  1151
# Valor= b'Euro' Tiempo restante=  1143
# Valor= b'Euro' Tiempo restante=  1138
# Valor= b'Euro' Tiempo restante=  1134
# Valor= b'Euro' Tiempo restante=  1127
# Valor= b'Euro' Tiempo restante=  1123
# Valor= b'Euro' Tiempo restante=  1119
# Valor= b'Euro' Tiempo restante=  1114
# Valor= b'Euro' Tiempo restante=  1110
# Valor= b'Euro' Tiempo restante=  1105
# Valor= b'Euro' Tiempo restante=  1101
# Valor= b'Euro' Tiempo restante=  1098
# Valor= b'Euro' Tiempo restante=  1094
# Valor= b'Euro' Tiempo restante=  1089
# Valor= b'Euro' Tiempo restante=  1085
# Valor= b'Euro' Tiempo restante=  1079
# Valor= b'Euro' Tiempo restante=  1073
# Valor= b'Euro' Tiempo restante=  1069
# Valor= b'Euro' Tiempo restante=  1062
# Valor= b'Euro' Tiempo restante=  1054
# Valor= b'Euro' Tiempo restante=  1051
# Valor= b'Euro' Tiempo restante=  1046
# Valor= b'Euro' Tiempo restante=  1042
# Valor= b'Euro' Tiempo restante=  1039
# Valor= b'Euro' Tiempo restante=  1035
# Valor= b'Euro' Tiempo restante=  1031
# Valor= b'Euro' Tiempo restante=  1027
# Valor= b'Euro' Tiempo restante=  1023
# Valor= b'Euro' Tiempo restante=  1020
# Valor= b'Euro' Tiempo restante=  1016
# Valor= b'Euro' Tiempo restante=  1010
# Valor= b'Euro' Tiempo restante=  1007
# Valor= b'Euro' Tiempo restante=  1003
# Valor= b'Euro' Tiempo restante=  1000
# Valor= b'Euro' Tiempo restante=  995
# Valor= b'Euro' Tiempo restante=  991
# Valor= b'Euro' Tiempo restante=  988
# Valor= b'Euro' Tiempo restante=  984
# Valor= b'Euro' Tiempo restante=  979
# Valor= b'Euro' Tiempo restante=  976
# Valor= b'Euro' Tiempo restante=  972
# Valor= b'Euro' Tiempo restante=  968
# Valor= b'Euro' Tiempo restante=  963
# Valor= b'Euro' Tiempo restante=  959
# Valor= b'Euro' Tiempo restante=  955
# Valor= b'Euro' Tiempo restante=  952
# Valor= b'Euro' Tiempo restante=  948
# Valor= b'Euro' Tiempo restante=  944
# Valor= b'Euro' Tiempo restante=  940
# Valor= b'Euro' Tiempo restante=  937
# Valor= b'Euro' Tiempo restante=  933
# Valor= b'Euro' Tiempo restante=  930
# Valor= b'Euro' Tiempo restante=  925
# Valor= b'Euro' Tiempo restante=  921
# Valor= b'Euro' Tiempo restante=  917
# Valor= b'Euro' Tiempo restante=  913
# Valor= b'Euro' Tiempo restante=  909
# Valor= b'Euro' Tiempo restante=  905
# Valor= b'Euro' Tiempo restante=  900
# Valor= b'Euro' Tiempo restante=  895
# Valor= b'Euro' Tiempo restante=  891
# Valor= b'Euro' Tiempo restante=  886
# Valor= b'Euro' Tiempo restante=  881
# Valor= b'Euro' Tiempo restante=  876
# Valor= b'Euro' Tiempo restante=  872
# Valor= b'Euro' Tiempo restante=  867
# Valor= b'Euro' Tiempo restante=  862
# Valor= b'Euro' Tiempo restante=  858
# Valor= b'Euro' Tiempo restante=  854
# Valor= b'Euro' Tiempo restante=  850
# Valor= b'Euro' Tiempo restante=  845
# Valor= b'Euro' Tiempo restante=  841
# Valor= b'Euro' Tiempo restante=  837
# Valor= b'Euro' Tiempo restante=  831
# Valor= b'Euro' Tiempo restante=  827
# Valor= b'Euro' Tiempo restante=  823
# Valor= b'Euro' Tiempo restante=  819
# Valor= b'Euro' Tiempo restante=  812
# Valor= b'Euro' Tiempo restante=  808
# Valor= b'Euro' Tiempo restante=  804
# Valor= b'Euro' Tiempo restante=  800
# Valor= b'Euro' Tiempo restante=  795
# Valor= b'Euro' Tiempo restante=  791
# Valor= b'Euro' Tiempo restante=  787
# Valor= b'Euro' Tiempo restante=  783
# Valor= b'Euro' Tiempo restante=  780
# Valor= b'Euro' Tiempo restante=  776
# Valor= b'Euro' Tiempo restante=  771
# Valor= b'Euro' Tiempo restante=  766
# Valor= b'Euro' Tiempo restante=  759
# Valor= b'Euro' Tiempo restante=  755
# Valor= b'Euro' Tiempo restante=  751
# Valor= b'Euro' Tiempo restante=  743
# Valor= b'Euro' Tiempo restante=  738
# Valor= b'Euro' Tiempo restante=  734
# Valor= b'Euro' Tiempo restante=  730
# Valor= b'Euro' Tiempo restante=  723
# Valor= b'Euro' Tiempo restante=  718
# Valor= b'Euro' Tiempo restante=  711
# Valor= b'Euro' Tiempo restante=  707
# Valor= b'Euro' Tiempo restante=  703
# Valor= b'Euro' Tiempo restante=  696
# Valor= b'Euro' Tiempo restante=  691
# Valor= b'Euro' Tiempo restante=  686
# Valor= b'Euro' Tiempo restante=  681
# Valor= b'Euro' Tiempo restante=  675
# Valor= b'Euro' Tiempo restante=  669
# Valor= b'Euro' Tiempo restante=  662
# Valor= b'Euro' Tiempo restante=  657
# Valor= b'Euro' Tiempo restante=  653
# Valor= b'Euro' Tiempo restante=  650
# Valor= b'Euro' Tiempo restante=  645
# Valor= b'Euro' Tiempo restante=  641
# Valor= b'Euro' Tiempo restante=  638
# Valor= b'Euro' Tiempo restante=  635
# Valor= b'Euro' Tiempo restante=  630
# Valor= b'Euro' Tiempo restante=  625
# Valor= b'Euro' Tiempo restante=  622
# Valor= b'Euro' Tiempo restante=  618
# Valor= b'Euro' Tiempo restante=  614
# Valor= b'Euro' Tiempo restante=  610
# Valor= b'Euro' Tiempo restante=  605
# Valor= b'Euro' Tiempo restante=  602
# Valor= b'Euro' Tiempo restante=  597
# Valor= b'Euro' Tiempo restante=  593
# Valor= b'Euro' Tiempo restante=  589
# Valor= b'Euro' Tiempo restante=  585
# Valor= b'Euro' Tiempo restante=  579
# Valor= b'Euro' Tiempo restante=  573
# Valor= b'Euro' Tiempo restante=  568
# Valor= b'Euro' Tiempo restante=  563
# Valor= b'Euro' Tiempo restante=  558
# Valor= b'Euro' Tiempo restante=  554
# Valor= b'Euro' Tiempo restante=  550
# Valor= b'Euro' Tiempo restante=  544
# Valor= b'Euro' Tiempo restante=  539
# Valor= b'Euro' Tiempo restante=  536
# Valor= b'Euro' Tiempo restante=  530
# Valor= b'Euro' Tiempo restante=  526
# Valor= b'Euro' Tiempo restante=  521
# Valor= b'Euro' Tiempo restante=  513
# Valor= b'Euro' Tiempo restante=  508
# Valor= b'Euro' Tiempo restante=  504
# Valor= b'Euro' Tiempo restante=  498
# Valor= b'Euro' Tiempo restante=  493
# Valor= b'Euro' Tiempo restante=  489
# Valor= b'Euro' Tiempo restante=  485
# Valor= b'Euro' Tiempo restante=  479
# Valor= b'Euro' Tiempo restante=  475
# Valor= b'Euro' Tiempo restante=  471
# Valor= b'Euro' Tiempo restante=  463
# Valor= b'Euro' Tiempo restante=  458
# Valor= b'Euro' Tiempo restante=  454
# Valor= b'Euro' Tiempo restante=  450
# Valor= b'Euro' Tiempo restante=  445
# Valor= b'Euro' Tiempo restante=  441
# Valor= b'Euro' Tiempo restante=  438
# Valor= b'Euro' Tiempo restante=  434
# Valor= b'Euro' Tiempo restante=  427
# Valor= b'Euro' Tiempo restante=  421
# Valor= b'Euro' Tiempo restante=  417
# Valor= b'Euro' Tiempo restante=  409
# Valor= b'Euro' Tiempo restante=  405
# Valor= b'Euro' Tiempo restante=  401
# Valor= b'Euro' Tiempo restante=  395
# Valor= b'Euro' Tiempo restante=  390
# Valor= b'Euro' Tiempo restante=  385
# Valor= b'Euro' Tiempo restante=  377
# Valor= b'Euro' Tiempo restante=  373
# Valor= b'Euro' Tiempo restante=  369
# Valor= b'Euro' Tiempo restante=  365
# Valor= b'Euro' Tiempo restante=  355
# Valor= b'Euro' Tiempo restante=  351
# Valor= b'Euro' Tiempo restante=  343
# Valor= b'Euro' Tiempo restante=  340
# Valor= b'Euro' Tiempo restante=  336
# Valor= b'Euro' Tiempo restante=  331
# Valor= b'Euro' Tiempo restante=  327
# Valor= b'Euro' Tiempo restante=  323
# Valor= b'Euro' Tiempo restante=  320
# Valor= b'Euro' Tiempo restante=  317
# Valor= b'Euro' Tiempo restante=  312
# Valor= b'Euro' Tiempo restante=  308
# Valor= b'Euro' Tiempo restante=  305
# Valor= b'Euro' Tiempo restante=  301
# Valor= b'Euro' Tiempo restante=  297
# Valor= b'Euro' Tiempo restante=  294
# Valor= b'Euro' Tiempo restante=  290
# Valor= b'Euro' Tiempo restante=  286
# Valor= b'Euro' Tiempo restante=  284
# Valor= b'Euro' Tiempo restante=  279
# Valor= b'Euro' Tiempo restante=  275
# Valor= b'Euro' Tiempo restante=  271
# Valor= b'Euro' Tiempo restante=  267
# Valor= b'Euro' Tiempo restante=  260
# Valor= b'Euro' Tiempo restante=  256
# Valor= b'Euro' Tiempo restante=  252
# Valor= b'Euro' Tiempo restante=  246
# Valor= b'Euro' Tiempo restante=  242
# Valor= b'Euro' Tiempo restante=  239
# Valor= b'Euro' Tiempo restante=  233
# Valor= b'Euro' Tiempo restante=  228
# Valor= b'Euro' Tiempo restante=  144
# Valor= b'Euro' Tiempo restante=  137
# Valor= b'Euro' Tiempo restante=  131
# Valor= b'Euro' Tiempo restante=  117
# Valor= b'Euro' Tiempo restante=  112
# Valor= b'Euro' Tiempo restante=  107
# Valor= b'Euro' Tiempo restante=  103
# Valor= b'Euro' Tiempo restante=  100
# Valor= b'Euro' Tiempo restante=  95
# Valor= b'Euro' Tiempo restante=  82
# Valor= b'Euro' Tiempo restante=  78
# Valor= b'Euro' Tiempo restante=  74
# Valor= b'Euro' Tiempo restante=  71
# Valor= b'Euro' Tiempo restante=  67
# Valor= b'Euro' Tiempo restante=  64
# Valor= b'Euro' Tiempo restante=  61
# Valor= b'Euro' Tiempo restante=  58
# Valor= b'Euro' Tiempo restante=  53
# Valor= b'Euro' Tiempo restante=  50
# Valor= b'Euro' Tiempo restante=  46
# Valor= b'Euro' Tiempo restante=  43
# Valor= b'Euro' Tiempo restante=  39
# Valor= b'Euro' Tiempo restante=  36
# Valor= b'Euro' Tiempo restante=  34
# Valor= b'Euro' Tiempo restante=  31
# Valor= b'Euro' Tiempo restante=  28
# Valor= b'Euro' Tiempo restante=  25
# Valor= b'Euro' Tiempo restante=  21
# Valor= b'Euro' Tiempo restante=  18
# Valor= b'Euro' Tiempo restante=  15
# Valor= b'Euro' Tiempo restante=  12
# Valor= b'Euro' Tiempo restante=  8
# Valor= b'Euro' Tiempo restante=  5
# Valor= b'Euro' Tiempo restante=  2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2

# %% [markdown]
# # Mini ejemplo 2

# %%
r.zadd('vehiculo', {'Auto' : 1})
r.zadd('vehiculo', {'Moto' : 2})
vehiculo = r.zrange('vehiculo', 0, -1, desc=False, withscores=True)
print(vehiculo)
# Out:
# [(b'Auto', 1.0), (b'Moto', 2.0)]

# %%
# Redis ordenamiento

judadores = 'Jugadores'
r.zadd(judadores, {'Ronaldo' : 100})
r.zadd(judadores, {'Messi' : 99})
r.zadd(judadores, {'Aguero' : 85})
r.zadd(judadores, {'Neymar' : 90})
r.zadd(judadores, {'Salah' : 89})

print("Cardinalidad:")
print(r.zcard(judadores))

print()
print("Cantidad de jugadores con rating entre 90-100:")
print(r.zcount(judadores, 90, 100))

print()
print("Cantidad de jugadores con rating entre 0-89:")
print(r.zcount(judadores, 0, 89))

print()
print("Buscar un valor:")
elementValue = "Messi"
print("Valor '{}' es ".format(elementValue), r.zscore(judadores, "Messi"))

print()
print("Ordenamiento de valores:")
print(r.zrangebyscore(judadores, min=0, max=100, withscores = True))

print()
print("Ordenamiento de valores reverso:")
print(r.zrevrangebyscore(judadores, min=0, max=100, withscores = True))
# Out:
# Cardinalidad:
# 5
#
# Cantidad de jugadores con rating entre 90-100:
# 3
#
# Cantidad de jugadores con rating entre 0-89:
# 2
#
# Buscar un valor:
# Valor 'Messi' es  99.0
#
# Ordenamiento de valores:
# [(b'Aguero', 85.0), (b'Salah', 89.0), (b'Neymar', 90.0), (b'Messi', 99.0), (b'Ronaldo', 100.0)]
#
# Ordenamiento de valores reverso:
# [(b'Ronaldo', 100.0), (b'Messi', 99.0), (b'Neymar', 90.0), (b'Salah', 89.0), (b'Aguero', 85.0)]

# %% [markdown]
# # Mini ejemplo 3

# %%
equipos = "Equipos"

r.zadd(equipos, {'Real Madrid': "1"})
r.zadd(equipos, {'Barcelona': "5"})
r.zadd(equipos, {'Juventus': "2"})
r.zadd(equipos, {'PSG': "3"})
r.zadd(equipos, {'Manchester United': "4"})
r.zadd(equipos, {'Milan': "5"})


print("Valores:")
print(r.zrange(equipos, 0, -1, desc=True, withscores=True))

print("Eliminar items:")
print(r.zrem(equipos, "Barcelona", "PSG"))

 
print("Eliminar items con valores:")
print(r.zremrangebyscore(equipos, 2, 5))

print("Visualizar items restantes:")
print(r.zrevrange(equipos, 0, -1, withscores=True))
# Out:
# Valores:
# [(b'Milan', 5.0), (b'Barcelona', 5.0), (b'Manchester United', 4.0), (b'PSG', 3.0), (b'Juventus', 2.0), (b'Real Madrid', 1.0)]
# Eliminar items:
# 2
# Eliminar items con valores:
# 3
# Visualizar items restantes:
# [(b'Real Madrid', 1.0)]

# %% [markdown]
# # Hash ejemplo 1

# %%
hash_value = 'redis_hash'
r.hset(hash_value, 1, "Uno")
r.hset(hash_value, 2, "Dos")
r.hset(hash_value, 3, "Tres")

print("Vaor para la clave 3")
print(r.hget(hash_value, 3))

 
print("Claves en redis hash:");
print(r.hkeys(hash_value))

print("Valores en redis hash:");
print(r.hvals(hash_value))


print("Claves y valores en redis hash:")
print(r.hgetall(hash_value))
# Out:
# Vaor para la clave 3
# b'Tres'
# Claves en redis hash:
# [b'1', b'2', b'3']
# Valores en redis hash:
# [b'Uno', b'Dos', b'Tres']
# Claves y valores en redis hash:
# {b'1': b'Uno', b'2': b'Dos', b'3': b'Tres'}

# %% [markdown]
# # Hash ejemplo 2

# %%
hash_value = "Cafes"
r.hset(hash_value, 1, "Corto")
r.hset(hash_value, 2, "Doble")
r.hset(hash_value, 3, "Capuchino")
r.hset(hash_value, 4, "Latte")

print(r.hgetall(hash_value))

r.hdel(hash_value, 1)
 
print(r.hgetall(hash_value))
# Out:
# {b'2': b'Doble', b'3': b'Capuchino', b'4': b'Latte', b'1': b'Corto'}
# {b'2': b'Doble', b'3': b'Capuchino', b'4': b'Latte'}

# %% [markdown]
# # Hash ejemplo 3

# %%
hash_value = "Libros"
r.hmset(hash_value,  {1:"Harry Potter y la piedra filosofal", 2:"Harry Potter y la cámara secreta"})

key = 1
print("La clave {} existe:".format(key))
print(r.hexists(hash_value, key)) # Verifico si la clave existe

print("Antes de la eliminación:")
print(r.hgetall(hash_value))

r.hdel(hash_value, key) # Eliminación de la clave

print("Despues de la eliminación de la clave:")
print(r.hgetall(hash_value))
# Out:
# La clave 1 existe:
# True
# Antes de la eliminación:
# {b'2': b'Harry Potter y la c\xc3\xa1mara secreta', b'1': b'Harry Potter y la piedra filosofal'}
# Despues de la eliminación de la clave:
# {b'2': b'Harry Potter y la c\xc3\xa1mara secreta'}
# <ipython-input-50-dd68a12009ed>:2: DeprecationWarning: Redis.hmset() is deprecated. Use Redis.hset() instead.
#   r.hmset(hash_value,  {1:"Harry Potter y la piedra filosofal", 2:"Harry Potter y la cámara secreta"})
