# %% [markdown]
# # Ejemplo de redis

# %% [markdown]
# ## Importar redis

# %%
import redis

# %% [markdown]
# ## Conexion al server de redis

# %%
r = redis.StrictRedis(
    host='127.0.0.1', 
    port=6379, 
    db=0, 
    password=None, 
    socket_timeout=None,
    connection_pool=None, 
    charset='utf-8', 
    errors='strict', 
    unix_socket_path=None)

# %% [markdown]
# ## Ejemplo preview Redis

# %%
# Seteo de clave-valor
r.set('Language', 'Python 2.x')

# Leer valores de clave
print(r.get('Language'))

# Seteo de clave-valor
r.set('Language', 'Python 3.x')

# Leer valores de clave
print(r.get('Language'))
# Out:
# b'Python 2.x'
# b'Python 3.x'

# %% [markdown]
# ## Elementos

# %% [markdown]
# ### Elementos Ejemplo 1

# %%
colores = "Colores"

# Agregar elementos
r.sadd(colores, "Rojo")
r.sadd(colores, "Verde")
r.sadd(colores, "Azul")

print("Cantidad de elementos:")
print(r.scard(colores))

print("Elementos:")
print(r.smembers(colores))
# Out:
# Cantidad de elementos:
# 3
# Elementos:
# {b'Rojo', b'Verde', b'Azul'}

# %% [markdown]
# ### Elementos Ejemplo 2

# %%
colores = "Colores"

# Agregar elementos
r.sadd(colores, "Rojo")
r.sadd(colores, "Verde")
r.sadd(colores, "Azul")

print("Cantidad de elementos:")
print(r.scard(colores))

print("Elementos:")
print(r.smembers(colores))

r.srem(colores, "Verde")  # Elimino elemento

print("Elementos luego de la eliminación:")
print(r.smembers(colores))

# Borrado de todos los elementos
while(r.scard(colores) > 0):
    print(f"Borrando {r.spop(colores)}")


print("Cantidad de elementos:")
print(r.scard(colores))
# Out:
# Cantidad de elementos:
# 3
# Elementos:
# {b'Rojo', b'Verde', b'Azul'}
# Elementos luego de la eliminación:
# {b'Rojo', b'Azul'}
# Borrando b'Azul'
# Borrando b'Rojo'
# Cantidad de elementos:
# 0

# %% [markdown]
# ## Funciones

# %% [markdown]
# ### Funciones Ejemplo 1

# %%
# Numeros primos
r.sadd("primos", 2, 3, 5, 7)
                          
# Funcion "sismember"
print(f'6 es primo? {r.sismember("primos", 6)}')                
print(f'7 es primo? {r.sismember("primos", 7)}')
# Out:
# 6 es primo? False
# 7 es primo? True

# %% [markdown]
# ### Funciones Ejemplo 2

# %%
# Sets de prueba
r.sadd("Jugadores1", "Messi",  "Ronaldo", "Neymar", "Salah")                               
r.sadd("Jugadores2", "Salah", "Aguero", "Ronaldo", "Benzema")                               
r.sadd("Jugadores3", "Benzema", "Lewandowski", "Aguero", "Sterling") 

# Función "Union"
print(r.sunion("Jugadores1","Jugadores2","Jugadores3"))

# Sets de prueba
r.sadd("Paises1", "Argentina", "Uruguay", "Brasil")                                
r.sadd("Paises2", "Brasil", "Chile", "Argentina")                               
r.sadd("Paises3", "Paraguay", "Argentina", "Chile") 

# Función "Union" en nuevo set
r.sunionstore("Paises4", "Paises1","Paises2","Paises3")
print(r.smembers("Paises4"))
# Out:
# {b'Salah', b'Aguero', b'Neymar', b'Lewandowski', b'Messi', b'Benzema', b'Sterling', b'Ronaldo'}
# {b'Brasil', b'Uruguay', b'Argentina', b'Chile', b'Paraguay'}

# %% [markdown]
# ### Funciones Ejemplo 3

# %%
# Sets de prueba
r.sadd("Jugadores10", "Messi",  "Ronaldo", "Neymar", "Salah")                               
r.sadd("Jugadores20", "Salah", "Aguero", "Ronaldo", "Messi")                               
r.sadd("Jugadores30", "Benzema", "Messi", "Aguero", "Sterling")                            

# Función "Intersección" de todos los sets
Jugadores40 = r.sinter("Jugadores10", "Jugadores20", "Jugadores30")
print("Intersección jugadores:")
print(Jugadores40)
 
# Sets de prueba
r.sadd("Paises10", "Argentina", "Uruguay", "Brasil")                                
r.sadd("Paises20", "Brasil", "Chile", "Argentina")                               
r.sadd("Paises30", "Paraguay", "Argentina", "Chile")                           

# Función "Intersección" de todos los sets en nuevo set
r.sinterstore("Paises40", "Paises10","Paises20","Paises30")
print("Intersección paises:")
print(r.smembers("Paises40"))
# Out:
# Intersección jugadores:
# {b'Messi'}
# Intersección paises:
# {b'Argentina'}

# %% [markdown]
# ### Funciones Ejemplo 4

# %%
# Sets de prueba
r.sadd("Jugadores100", "Messi",  "Ronaldo", "Neymar", "Salah")                               
r.sadd("Jugadores200", "Salah")                               
r.sadd("Jugadores300", "Ronaldo")         

# Valores que no estan en todos los sets
print(r.sdiff("Jugadores100", "Jugadores200", "Jugadores300"))

# Sets de prueba
r.sadd("Paises100", "Argentina", "Uruguay", "Brasil")                                
r.sadd("Paises200", "Brasil", "Chile", "Argentina")                               
r.sadd("Paises300", "Paraguay", "Argentina", "Chile")   

# Encontrar si algun valor del set "Paises100" no estan en los otros sets
r.sdiffstore("Paises400", "Paises100", "Paises200", "Paises300")
print(r.smembers("Paises400"))
# Out:
# {b'Messi', b'Neymar'}
# {b'Uruguay'}

# %% [markdown]
# ## Listas

# %% [markdown]
# ### Listas Ejemplo 1

# %%
# Agregar valores a la lista 
# lpush = head list
r.lpush('Paises', "Argentina")
r.lpush('Paises', "Chile")

# Agregar multiples valores a la lista
r.lpush('Paises', "Brasil", "Uruguay")

# Imprimir valores de la lista y liberarlos
while(r.llen('Paises')!=0):
    print(r.lpop('Paises'))
# Out:
# b'Uruguay'
# b'Brasil'
# b'Chile'
# b'Argentina'

# %% [markdown]
# ### Listas Ejemplo 2

# %%
# Agregar valores a la lista 
# rpush = tail list
paises = "Paises"
r.rpush(paises, "Italia")
r.rpush(paises, "Portugal")
r.rpush(paises, "Alemania")
r.rpush(paises, "Francia")
r.rpush(paises, "Austria")

# Agregar multiples valores a la lista
r.rpush(paises, "Grecia", "Inglaterra")

# Imprimir valores de la lista y liberarlos
while(r.llen(paises)!=0):
    print(r.rpop(paises))
# Out:
# b'Inglaterra'
# b'Grecia'
# b'Austria'
# b'Francia'
# b'Alemania'
# b'Portugal'
# b'Italia'

# %% [markdown]
# ### Listas Ejemplo 3

# %%
# Lista con todos ceros
lista = "numeros"
r.lpush(lista, 0,0,0,0,0)

print("Lista sin cambios:")
for i in range(0, r.llen(lista)):
    print(r.lindex(lista, i))

# Modificando lista
for i in range(0, r.llen(lista)):
    r.lset(lista, i, i*2)

print("Lista modificada:")
for i in range(0, r.llen(lista)):
    print(r.lindex(lista, i))

print("Longuitud de la lista antes de liberarlos:")
print(r.llen(lista)) 

# Liberando la lista
for i in range(0, r.llen(lista)):
    r.lpop(lista)

print("Longuitud de la lista despues de liberarlos:")
print(r.llen(lista))
# Out:
# Lista sin cambios:
# b'0'
# b'0'
# b'0'
# b'0'
# b'0'
# b'2'
# b'4'
# b'6'
# b'8'
# Lista modificada:
# b'0'
# b'2'
# b'4'
# b'6'
# b'8'
# b'10'
# b'12'
# b'14'
# b'16'
# Longuitud de la lista antes de liberarlos:
# 9
# Longuitud de la lista despues de liberarlos:
# 0

# %% [markdown]
# ### Listas Ejemplo 4

# %%
# Lista con numeros
lista = "numeros"
r.rpush(lista, 2,4,6,8,10,12)

print("Lista antes de cambio:")
for i in range(0, r.llen(lista)):
    print(r.lindex(lista,i))

startIndex  = 0
endIndex    = 3
nueva_lista     = r.ltrim(lista, startIndex, endIndex)  # Trim de lista con numero enteros

print("Lista luego de cambio:")
for i in range(0, r.llen(lista)):
    print(r.lindex(lista,i))
# Out:
# Lista antes de cambio:
# b'2'
# b'4'
# b'6'
# b'8'
# b'10'
# b'12'
# Lista luego de cambio:
# b'2'
# b'4'
# b'6'
# b'8'

# %% [markdown]
# ## Hash

# %% [markdown]
# ### Hash Ejemplo 1

# %%
hash_value = 'redis_hash'
r.hset(hash_value, 1, "Uno")
r.hset(hash_value, 2, "Dos")
r.hset(hash_value, 3, "Tres")

print("Vaor para la clave 3")
print(r.hget(hash_value, 3))

 
print("Claves en redis hash:")
print(r.hkeys(hash_value))

print("Valores en redis hash:")
print(r.hvals(hash_value))


print("Claves y valores en redis hash:")
print(r.hgetall(hash_value))
# Out:
# Vaor para la clave 3
# b'Tres'
# Claves en redis hash:
# [b'1', b'2', b'3']
# Valores en redis hash:
# [b'Uno', b'Dos', b'Tres']
# Claves y valores en redis hash:
# {b'1': b'Uno', b'2': b'Dos', b'3': b'Tres'}

# %% [markdown]
# ### Hash Ejemplo 2

# %%
hash_value = "Cafes"
r.hset(hash_value, 1, "Corto")
r.hset(hash_value, 2, "Doble")
r.hset(hash_value, 3, "Capuchino")
r.hset(hash_value, 4, "Latte")

print(r.hgetall(hash_value))

# Eliminación de clave
r.hdel(hash_value, 1)

# Print claves
print(r.hgetall(hash_value))
# Out:
# {b'2': b'Doble', b'3': b'Capuchino', b'4': b'Latte', b'1': b'Corto'}
# {b'2': b'Doble', b'3': b'Capuchino', b'4': b'Latte'}

# %% [markdown]
# ### Hash Ejemplo 3

# %%
hash_value = "Libros"
r.hmset(hash_value,  {1:"Harry Potter y la piedra filosofal", 2:"Harry Potter y la cámara secreta"})

key = 1
print(f"La clave {key} existe:")
print(r.hexists(hash_value, key)) # Verifico si la clave existe

print("Antes de la eliminación:")
print(r.hgetall(hash_value))

r.hdel(hash_value, key) # Eliminación de la clave

print("Despues de la eliminación de la clave:")
print(r.hgetall(hash_value))
# Out:
# La clave 1 existe:
# True
# Antes de la eliminación:
# {b'2': b'Harry Potter y la c\xc3\xa1mara secreta', b'1': b'Harry Potter y la piedra filosofal'}
# Despues de la eliminación de la clave:
# {b'2': b'Harry Potter y la c\xc3\xa1mara secreta'}
# <ipython-input-372-16b68f97164a>:2: DeprecationWarning: Redis.hmset() is deprecated. Use Redis.hset() instead.
#   r.hmset(hash_value,  {1:"Harry Potter y la piedra filosofal", 2:"Harry Potter y la cámara secreta"})

# %% [markdown]
# ## Ciclo de vida

# %% [markdown]
# ### Seteo de clave valor

# %%
r.set('Moneda','Pesos')
r.get('Moneda')
# Out:
# b'Pesos'

# %% [markdown]
# ### Seteo de ciclo de vida de lo almacenado

# %%
r.set('Moneda','Dolar', ex=10)
# Out:
# True

# %% [markdown]
# ### Tiempo de vida restante de la data dentro de regis

# %%
r.pttl('Moneda')
# Out:
# 9943

# %% [markdown]
# ### Seteo de persistencia

# %%
r.persist('Moneda')
# Out:
# True

# %% [markdown]
# ### Ciclo de vida Ejemplo 1

# %%
import time

r.set('Moneda','Euro', ex=3) # 3 segundos de time to live
t_end = time.time() + 4      # 4 segundos de check

while time.time() < t_end:
    print("Valor=" ,r.get('Moneda'), "Tiempo restante= ", r.pttl('Moneda'))
# Out:
# Valor= b'Euro' Tiempo restante=  2994
# Valor= b'Euro' Tiempo restante=  2990
# Valor= b'Euro' Tiempo restante=  2983
# Valor= b'Euro' Tiempo restante=  2977
# Valor= b'Euro' Tiempo restante=  2973
# Valor= b'Euro' Tiempo restante=  2968
# Valor= b'Euro' Tiempo restante=  2963
# Valor= b'Euro' Tiempo restante=  2959
# Valor= b'Euro' Tiempo restante=  2955
# Valor= b'Euro' Tiempo restante=  2949
# Valor= b'Euro' Tiempo restante=  2943
# Valor= b'Euro' Tiempo restante=  2940
# Valor= b'Euro' Tiempo restante=  2936
# Valor= b'Euro' Tiempo restante=  2931
# Valor= b'Euro' Tiempo restante=  2926
# Valor= b'Euro' Tiempo restante=  2921
# Valor= b'Euro' Tiempo restante=  2915
# Valor= b'Euro' Tiempo restante=  2911
# Valor= b'Euro' Tiempo restante=  2907
# Valor= b'Euro' Tiempo restante=  2902
# Valor= b'Euro' Tiempo restante=  2895
# Valor= b'Euro' Tiempo restante=  2889
# Valor= b'Euro' Tiempo restante=  2884
# Valor= b'Euro' Tiempo restante=  2877
# Valor= b'Euro' Tiempo restante=  2873
# Valor= b'Euro' Tiempo restante=  2869
# Valor= b'Euro' Tiempo restante=  2862
# Valor= b'Euro' Tiempo restante=  2857
# Valor= b'Euro' Tiempo restante=  2850
# Valor= b'Euro' Tiempo restante=  2846
# Valor= b'Euro' Tiempo restante=  2842
# Valor= b'Euro' Tiempo restante=  2838
# Valor= b'Euro' Tiempo restante=  2832
# Valor= b'Euro' Tiempo restante=  2827
# Valor= b'Euro' Tiempo restante=  2823
# Valor= b'Euro' Tiempo restante=  2816
# Valor= b'Euro' Tiempo restante=  2810
# Valor= b'Euro' Tiempo restante=  2805
# Valor= b'Euro' Tiempo restante=  2802
# Valor= b'Euro' Tiempo restante=  2793
# Valor= b'Euro' Tiempo restante=  2790
# Valor= b'Euro' Tiempo restante=  2785
# Valor= b'Euro' Tiempo restante=  2780
# Valor= b'Euro' Tiempo restante=  2776
# Valor= b'Euro' Tiempo restante=  2772
# Valor= b'Euro' Tiempo restante=  2764
# Valor= b'Euro' Tiempo restante=  2760
# Valor= b'Euro' Tiempo restante=  2755
# Valor= b'Euro' Tiempo restante=  2750
# Valor= b'Euro' Tiempo restante=  2746
# Valor= b'Euro' Tiempo restante=  2743
# Valor= b'Euro' Tiempo restante=  2738
# Valor= b'Euro' Tiempo restante=  2732
# Valor= b'Euro' Tiempo restante=  2728
# Valor= b'Euro' Tiempo restante=  2724
# Valor= b'Euro' Tiempo restante=  2721
# Valor= b'Euro' Tiempo restante=  2713
# Valor= b'Euro' Tiempo restante=  2708
# Valor= b'Euro' Tiempo restante=  2704
# Valor= b'Euro' Tiempo restante=  2700
# Valor= b'Euro' Tiempo restante=  2693
# Valor= b'Euro' Tiempo restante=  2689
# Valor= b'Euro' Tiempo restante=  2682
# Valor= b'Euro' Tiempo restante=  2677
# Valor= b'Euro' Tiempo restante=  2673
# Valor= b'Euro' Tiempo restante=  2666
# Valor= b'Euro' Tiempo restante=  2659
# Valor= b'Euro' Tiempo restante=  2655
# Valor= b'Euro' Tiempo restante=  2531
# Valor= b'Euro' Tiempo restante=  2525
# Valor= b'Euro' Tiempo restante=  2521
# Valor= b'Euro' Tiempo restante=  2510
# Valor= b'Euro' Tiempo restante=  2506
# Valor= b'Euro' Tiempo restante=  2500
# Valor= b'Euro' Tiempo restante=  2495
# Valor= b'Euro' Tiempo restante=  2491
# Valor= b'Euro' Tiempo restante=  2487
# Valor= b'Euro' Tiempo restante=  2481
# Valor= b'Euro' Tiempo restante=  2443
# Valor= b'Euro' Tiempo restante=  2439
# Valor= b'Euro' Tiempo restante=  2436
# Valor= b'Euro' Tiempo restante=  2430
# Valor= b'Euro' Tiempo restante=  2426
# Valor= b'Euro' Tiempo restante=  2422
# Valor= b'Euro' Tiempo restante=  2420
# Valor= b'Euro' Tiempo restante=  2414
# Valor= b'Euro' Tiempo restante=  2410
# Valor= b'Euro' Tiempo restante=  2406
# Valor= b'Euro' Tiempo restante=  2403
# Valor= b'Euro' Tiempo restante=  2399
# Valor= b'Euro' Tiempo restante=  2395
# Valor= b'Euro' Tiempo restante=  2391
# Valor= b'Euro' Tiempo restante=  2387
# Valor= b'Euro' Tiempo restante=  2383
# Valor= b'Euro' Tiempo restante=  2379
# Valor= b'Euro' Tiempo restante=  2375
# Valor= b'Euro' Tiempo restante=  2372
# Valor= b'Euro' Tiempo restante=  2369
# Valor= b'Euro' Tiempo restante=  2364
# Valor= b'Euro' Tiempo restante=  2360
# Valor= b'Euro' Tiempo restante=  2357
# Valor= b'Euro' Tiempo restante=  2354
# Valor= b'Euro' Tiempo restante=  2349
# Valor= b'Euro' Tiempo restante=  2345
# Valor= b'Euro' Tiempo restante=  2342
# Valor= b'Euro' Tiempo restante=  2339
# Valor= b'Euro' Tiempo restante=  2334
# Valor= b'Euro' Tiempo restante=  2329
# Valor= b'Euro' Tiempo restante=  2326
# Valor= b'Euro' Tiempo restante=  2322
# Valor= b'Euro' Tiempo restante=  2318
# Valor= b'Euro' Tiempo restante=  2313
# Valor= b'Euro' Tiempo restante=  2310
# Valor= b'Euro' Tiempo restante=  2307
# Valor= b'Euro' Tiempo restante=  2303
# Valor= b'Euro' Tiempo restante=  2297
# Valor= b'Euro' Tiempo restante=  2293
# Valor= b'Euro' Tiempo restante=  2290
# Valor= b'Euro' Tiempo restante=  2287
# Valor= b'Euro' Tiempo restante=  2283
# Valor= b'Euro' Tiempo restante=  2279
# Valor= b'Euro' Tiempo restante=  2272
# Valor= b'Euro' Tiempo restante=  2269
# Valor= b'Euro' Tiempo restante=  2264
# Valor= b'Euro' Tiempo restante=  2260
# Valor= b'Euro' Tiempo restante=  2254
# Valor= b'Euro' Tiempo restante=  2248
# Valor= b'Euro' Tiempo restante=  2243
# Valor= b'Euro' Tiempo restante=  2239
# Valor= b'Euro' Tiempo restante=  2235
# Valor= b'Euro' Tiempo restante=  2229
# Valor= b'Euro' Tiempo restante=  2224
# Valor= b'Euro' Tiempo restante=  2221
# Valor= b'Euro' Tiempo restante=  2215
# Valor= b'Euro' Tiempo restante=  2211
# Valor= b'Euro' Tiempo restante=  2208
# Valor= b'Euro' Tiempo restante=  2204
# Valor= b'Euro' Tiempo restante=  2201
# Valor= b'Euro' Tiempo restante=  2196
# Valor= b'Euro' Tiempo restante=  2192
# Valor= b'Euro' Tiempo restante=  2189
# Valor= b'Euro' Tiempo restante=  2185
# Valor= b'Euro' Tiempo restante=  2181
# Valor= b'Euro' Tiempo restante=  2177
# Valor= b'Euro' Tiempo restante=  2174
# Valor= b'Euro' Tiempo restante=  2171
# Valor= b'Euro' Tiempo restante=  2167
# Valor= b'Euro' Tiempo restante=  2163
# Valor= b'Euro' Tiempo restante=  2160
# Valor= b'Euro' Tiempo restante=  2156
# Valor= b'Euro' Tiempo restante=  2154
# Valor= b'Euro' Tiempo restante=  2149
# Valor= b'Euro' Tiempo restante=  2145
# Valor= b'Euro' Tiempo restante=  2142
# Valor= b'Euro' Tiempo restante=  2139
# Valor= b'Euro' Tiempo restante=  2134
# Valor= b'Euro' Tiempo restante=  2130
# Valor= b'Euro' Tiempo restante=  2126
# Valor= b'Euro' Tiempo restante=  2123
# Valor= b'Euro' Tiempo restante=  2120
# Valor= b'Euro' Tiempo restante=  2114
# Valor= b'Euro' Tiempo restante=  2110
# Valor= b'Euro' Tiempo restante=  2107
# Valor= b'Euro' Tiempo restante=  2103
# Valor= b'Euro' Tiempo restante=  2097
# Valor= b'Euro' Tiempo restante=  2093
# Valor= b'Euro' Tiempo restante=  2089
# Valor= b'Euro' Tiempo restante=  2084
# Valor= b'Euro' Tiempo restante=  2080
# Valor= b'Euro' Tiempo restante=  2076
# Valor= b'Euro' Tiempo restante=  2072
# Valor= b'Euro' Tiempo restante=  2067
# Valor= b'Euro' Tiempo restante=  2062
# Valor= b'Euro' Tiempo restante=  2059
# Valor= b'Euro' Tiempo restante=  2057
# Valor= b'Euro' Tiempo restante=  2054
# Valor= b'Euro' Tiempo restante=  2050
# Valor= b'Euro' Tiempo restante=  2045
# Valor= b'Euro' Tiempo restante=  2042
# Valor= b'Euro' Tiempo restante=  2038
# Valor= b'Euro' Tiempo restante=  2032
# Valor= b'Euro' Tiempo restante=  2028
# Valor= b'Euro' Tiempo restante=  2024
# Valor= b'Euro' Tiempo restante=  2021
# Valor= b'Euro' Tiempo restante=  2015
# Valor= b'Euro' Tiempo restante=  2011
# Valor= b'Euro' Tiempo restante=  2007
# Valor= b'Euro' Tiempo restante=  2004
# Valor= b'Euro' Tiempo restante=  1999
# Valor= b'Euro' Tiempo restante=  1994
# Valor= b'Euro' Tiempo restante=  1991
# Valor= b'Euro' Tiempo restante=  1988
# Valor= b'Euro' Tiempo restante=  1983
# Valor= b'Euro' Tiempo restante=  1978
# Valor= b'Euro' Tiempo restante=  1975
# Valor= b'Euro' Tiempo restante=  1972
# Valor= b'Euro' Tiempo restante=  1967
# Valor= b'Euro' Tiempo restante=  1962
# Valor= b'Euro' Tiempo restante=  1958
# Valor= b'Euro' Tiempo restante=  1955
# Valor= b'Euro' Tiempo restante=  1951
# Valor= b'Euro' Tiempo restante=  1946
# Valor= b'Euro' Tiempo restante=  1943
# Valor= b'Euro' Tiempo restante=  1940
# Valor= b'Euro' Tiempo restante=  1936
# Valor= b'Euro' Tiempo restante=  1931
# Valor= b'Euro' Tiempo restante=  1927
# Valor= b'Euro' Tiempo restante=  1924
# Valor= b'Euro' Tiempo restante=  1921
# Valor= b'Euro' Tiempo restante=  1915
# Valor= b'Euro' Tiempo restante=  1911
# Valor= b'Euro' Tiempo restante=  1908
# Valor= b'Euro' Tiempo restante=  1905
# Valor= b'Euro' Tiempo restante=  1900
# Valor= b'Euro' Tiempo restante=  1895
# Valor= b'Euro' Tiempo restante=  1891
# Valor= b'Euro' Tiempo restante=  1887
# Valor= b'Euro' Tiempo restante=  1881
# Valor= b'Euro' Tiempo restante=  1877
# Valor= b'Euro' Tiempo restante=  1874
# Valor= b'Euro' Tiempo restante=  1871
# Valor= b'Euro' Tiempo restante=  1867
# Valor= b'Euro' Tiempo restante=  1863
# Valor= b'Euro' Tiempo restante=  1859
# Valor= b'Euro' Tiempo restante=  1856
# Valor= b'Euro' Tiempo restante=  1853
# Valor= b'Euro' Tiempo restante=  1848
# Valor= b'Euro' Tiempo restante=  1844
# Valor= b'Euro' Tiempo restante=  1841
# Valor= b'Euro' Tiempo restante=  1838
# Valor= b'Euro' Tiempo restante=  1834
# Valor= b'Euro' Tiempo restante=  1828
# Valor= b'Euro' Tiempo restante=  1825
# Valor= b'Euro' Tiempo restante=  1821
# Valor= b'Euro' Tiempo restante=  1815
# Valor= b'Euro' Tiempo restante=  1811
# Valor= b'Euro' Tiempo restante=  1808
# Valor= b'Euro' Tiempo restante=  1804
# Valor= b'Euro' Tiempo restante=  1799
# Valor= b'Euro' Tiempo restante=  1794
# Valor= b'Euro' Tiempo restante=  1791
# Valor= b'Euro' Tiempo restante=  1788
# Valor= b'Euro' Tiempo restante=  1783
# Valor= b'Euro' Tiempo restante=  1779
# Valor= b'Euro' Tiempo restante=  1775
# Valor= b'Euro' Tiempo restante=  1772
# Valor= b'Euro' Tiempo restante=  1769
# Valor= b'Euro' Tiempo restante=  1764
# Valor= b'Euro' Tiempo restante=  1761
# Valor= b'Euro' Tiempo restante=  1757
# Valor= b'Euro' Tiempo restante=  1754
# Valor= b'Euro' Tiempo restante=  1749
# Valor= b'Euro' Tiempo restante=  1746
# Valor= b'Euro' Tiempo restante=  1742
# Valor= b'Euro' Tiempo restante=  1739
# Valor= b'Euro' Tiempo restante=  1736
# Valor= b'Euro' Tiempo restante=  1733
# Valor= b'Euro' Tiempo restante=  1729
# Valor= b'Euro' Tiempo restante=  1725
# Valor= b'Euro' Tiempo restante=  1722
# Valor= b'Euro' Tiempo restante=  1719
# Valor= b'Euro' Tiempo restante=  1709
# Valor= b'Euro' Tiempo restante=  1706
# Valor= b'Euro' Tiempo restante=  1701
# Valor= b'Euro' Tiempo restante=  1697
# Valor= b'Euro' Tiempo restante=  1692
# Valor= b'Euro' Tiempo restante=  1688
# Valor= b'Euro' Tiempo restante=  1683
# Valor= b'Euro' Tiempo restante=  1679
# Valor= b'Euro' Tiempo restante=  1676
# Valor= b'Euro' Tiempo restante=  1673
# Valor= b'Euro' Tiempo restante=  1670
# Valor= b'Euro' Tiempo restante=  1666
# Valor= b'Euro' Tiempo restante=  1663
# Valor= b'Euro' Tiempo restante=  1660
# Valor= b'Euro' Tiempo restante=  1655
# Valor= b'Euro' Tiempo restante=  1650
# Valor= b'Euro' Tiempo restante=  1645
# Valor= b'Euro' Tiempo restante=  1642
# Valor= b'Euro' Tiempo restante=  1639
# Valor= b'Euro' Tiempo restante=  1635
# Valor= b'Euro' Tiempo restante=  1630
# Valor= b'Euro' Tiempo restante=  1627
# Valor= b'Euro' Tiempo restante=  1624
# Valor= b'Euro' Tiempo restante=  1621
# Valor= b'Euro' Tiempo restante=  1616
# Valor= b'Euro' Tiempo restante=  1613
# Valor= b'Euro' Tiempo restante=  1609
# Valor= b'Euro' Tiempo restante=  1606
# Valor= b'Euro' Tiempo restante=  1599
# Valor= b'Euro' Tiempo restante=  1594
# Valor= b'Euro' Tiempo restante=  1591
# Valor= b'Euro' Tiempo restante=  1588
# Valor= b'Euro' Tiempo restante=  1584
# Valor= b'Euro' Tiempo restante=  1578
# Valor= b'Euro' Tiempo restante=  1575
# Valor= b'Euro' Tiempo restante=  1572
# Valor= b'Euro' Tiempo restante=  1568
# Valor= b'Euro' Tiempo restante=  1564
# Valor= b'Euro' Tiempo restante=  1561
# Valor= b'Euro' Tiempo restante=  1557
# Valor= b'Euro' Tiempo restante=  1554
# Valor= b'Euro' Tiempo restante=  1550
# Valor= b'Euro' Tiempo restante=  1547
# Valor= b'Euro' Tiempo restante=  1543
# Valor= b'Euro' Tiempo restante=  1540
# Valor= b'Euro' Tiempo restante=  1537
# Valor= b'Euro' Tiempo restante=  1532
# Valor= b'Euro' Tiempo restante=  1528
# Valor= b'Euro' Tiempo restante=  1525
# Valor= b'Euro' Tiempo restante=  1523
# Valor= b'Euro' Tiempo restante=  1517
# Valor= b'Euro' Tiempo restante=  1509
# Valor= b'Euro' Tiempo restante=  1504
# Valor= b'Euro' Tiempo restante=  1499
# Valor= b'Euro' Tiempo restante=  1494
# Valor= b'Euro' Tiempo restante=  1490
# Valor= b'Euro' Tiempo restante=  1486
# Valor= b'Euro' Tiempo restante=  1481
# Valor= b'Euro' Tiempo restante=  1478
# Valor= b'Euro' Tiempo restante=  1473
# Valor= b'Euro' Tiempo restante=  1466
# Valor= b'Euro' Tiempo restante=  1461
# Valor= b'Euro' Tiempo restante=  1459
# Valor= b'Euro' Tiempo restante=  1456
# Valor= b'Euro' Tiempo restante=  1453
# Valor= b'Euro' Tiempo restante=  1448
# Valor= b'Euro' Tiempo restante=  1445
# Valor= b'Euro' Tiempo restante=  1442
# Valor= b'Euro' Tiempo restante=  1439
# Valor= b'Euro' Tiempo restante=  1434
# Valor= b'Euro' Tiempo restante=  1430
# Valor= b'Euro' Tiempo restante=  1427
# Valor= b'Euro' Tiempo restante=  1424
# Valor= b'Euro' Tiempo restante=  1421
# Valor= b'Euro' Tiempo restante=  1416
# Valor= b'Euro' Tiempo restante=  1412
# Valor= b'Euro' Tiempo restante=  1410
# Valor= b'Euro' Tiempo restante=  1407
# Valor= b'Euro' Tiempo restante=  1404
# Valor= b'Euro' Tiempo restante=  1399
# Valor= b'Euro' Tiempo restante=  1394
# Valor= b'Euro' Tiempo restante=  1390
# Valor= b'Euro' Tiempo restante=  1387
# Valor= b'Euro' Tiempo restante=  1380
# Valor= b'Euro' Tiempo restante=  1376
# Valor= b'Euro' Tiempo restante=  1374
# Valor= b'Euro' Tiempo restante=  1371
# Valor= b'Euro' Tiempo restante=  1367
# Valor= b'Euro' Tiempo restante=  1364
# Valor= b'Euro' Tiempo restante=  1360
# Valor= b'Euro' Tiempo restante=  1357
# Valor= b'Euro' Tiempo restante=  1354
# Valor= b'Euro' Tiempo restante=  1349
# Valor= b'Euro' Tiempo restante=  1345
# Valor= b'Euro' Tiempo restante=  1342
# Valor= b'Euro' Tiempo restante=  1338
# Valor= b'Euro' Tiempo restante=  1334
# Valor= b'Euro' Tiempo restante=  1330
# Valor= b'Euro' Tiempo restante=  1327
# Valor= b'Euro' Tiempo restante=  1324
# Valor= b'Euro' Tiempo restante=  1321
# Valor= b'Euro' Tiempo restante=  1316
# Valor= b'Euro' Tiempo restante=  1313
# Valor= b'Euro' Tiempo restante=  1309
# Valor= b'Euro' Tiempo restante=  1306
# Valor= b'Euro' Tiempo restante=  1303
# Valor= b'Euro' Tiempo restante=  1299
# Valor= b'Euro' Tiempo restante=  1294
# Valor= b'Euro' Tiempo restante=  1291
# Valor= b'Euro' Tiempo restante=  1288
# Valor= b'Euro' Tiempo restante=  1283
# Valor= b'Euro' Tiempo restante=  1278
# Valor= b'Euro' Tiempo restante=  1274
# Valor= b'Euro' Tiempo restante=  1270
# Valor= b'Euro' Tiempo restante=  1266
# Valor= b'Euro' Tiempo restante=  1262
# Valor= b'Euro' Tiempo restante=  1259
# Valor= b'Euro' Tiempo restante=  1256
# Valor= b'Euro' Tiempo restante=  1250
# Valor= b'Euro' Tiempo restante=  1246
# Valor= b'Euro' Tiempo restante=  1242
# Valor= b'Euro' Tiempo restante=  1239
# Valor= b'Euro' Tiempo restante=  1233
# Valor= b'Euro' Tiempo restante=  1229
# Valor= b'Euro' Tiempo restante=  1225
# Valor= b'Euro' Tiempo restante=  1221
# Valor= b'Euro' Tiempo restante=  1216
# Valor= b'Euro' Tiempo restante=  1211
# Valor= b'Euro' Tiempo restante=  1207
# Valor= b'Euro' Tiempo restante=  1203
# Valor= b'Euro' Tiempo restante=  1197
# Valor= b'Euro' Tiempo restante=  1193
# Valor= b'Euro' Tiempo restante=  1190
# Valor= b'Euro' Tiempo restante=  1186
# Valor= b'Euro' Tiempo restante=  1177
# Valor= b'Euro' Tiempo restante=  1171
# Valor= b'Euro' Tiempo restante=  1164
# Valor= b'Euro' Tiempo restante=  1160
# Valor= b'Euro' Tiempo restante=  1157
# Valor= b'Euro' Tiempo restante=  1154
# Valor= b'Euro' Tiempo restante=  1150
# Valor= b'Euro' Tiempo restante=  1145
# Valor= b'Euro' Tiempo restante=  1141
# Valor= b'Euro' Tiempo restante=  1138
# Valor= b'Euro' Tiempo restante=  1132
# Valor= b'Euro' Tiempo restante=  1128
# Valor= b'Euro' Tiempo restante=  1125
# Valor= b'Euro' Tiempo restante=  1122
# Valor= b'Euro' Tiempo restante=  1117
# Valor= b'Euro' Tiempo restante=  1112
# Valor= b'Euro' Tiempo restante=  1109
# Valor= b'Euro' Tiempo restante=  1105
# Valor= b'Euro' Tiempo restante=  1100
# Valor= b'Euro' Tiempo restante=  1095
# Valor= b'Euro' Tiempo restante=  1091
# Valor= b'Euro' Tiempo restante=  1088
# Valor= b'Euro' Tiempo restante=  1083
# Valor= b'Euro' Tiempo restante=  1080
# Valor= b'Euro' Tiempo restante=  1077
# Valor= b'Euro' Tiempo restante=  1073
# Valor= b'Euro' Tiempo restante=  1066
# Valor= b'Euro' Tiempo restante=  1061
# Valor= b'Euro' Tiempo restante=  1058
# Valor= b'Euro' Tiempo restante=  1055
# Valor= b'Euro' Tiempo restante=  1049
# Valor= b'Euro' Tiempo restante=  1044
# Valor= b'Euro' Tiempo restante=  1040
# Valor= b'Euro' Tiempo restante=  1037
# Valor= b'Euro' Tiempo restante=  1031
# Valor= b'Euro' Tiempo restante=  1027
# Valor= b'Euro' Tiempo restante=  1024
# Valor= b'Euro' Tiempo restante=  1021
# Valor= b'Euro' Tiempo restante=  1015
# Valor= b'Euro' Tiempo restante=  1011
# Valor= b'Euro' Tiempo restante=  1007
# Valor= b'Euro' Tiempo restante=  1004
# Valor= b'Euro' Tiempo restante=  1000
# Valor= b'Euro' Tiempo restante=  995
# Valor= b'Euro' Tiempo restante=  991
# Valor= b'Euro' Tiempo restante=  988
# Valor= b'Euro' Tiempo restante=  981
# Valor= b'Euro' Tiempo restante=  977
# Valor= b'Euro' Tiempo restante=  973
# Valor= b'Euro' Tiempo restante=  970
# Valor= b'Euro' Tiempo restante=  964
# Valor= b'Euro' Tiempo restante=  960
# Valor= b'Euro' Tiempo restante=  956
# Valor= b'Euro' Tiempo restante=  953
# Valor= b'Euro' Tiempo restante=  946
# Valor= b'Euro' Tiempo restante=  943
# Valor= b'Euro' Tiempo restante=  939
# Valor= b'Euro' Tiempo restante=  934
# Valor= b'Euro' Tiempo restante=  930
# Valor= b'Euro' Tiempo restante=  926
# Valor= b'Euro' Tiempo restante=  923
# Valor= b'Euro' Tiempo restante=  920
# Valor= b'Euro' Tiempo restante=  914
# Valor= b'Euro' Tiempo restante=  911
# Valor= b'Euro' Tiempo restante=  907
# Valor= b'Euro' Tiempo restante=  903
# Valor= b'Euro' Tiempo restante=  897
# Valor= b'Euro' Tiempo restante=  894
# Valor= b'Euro' Tiempo restante=  890
# Valor= b'Euro' Tiempo restante=  887
# Valor= b'Euro' Tiempo restante=  881
# Valor= b'Euro' Tiempo restante=  877
# Valor= b'Euro' Tiempo restante=  873
# Valor= b'Euro' Tiempo restante=  869
# Valor= b'Euro' Tiempo restante=  863
# Valor= b'Euro' Tiempo restante=  859
# Valor= b'Euro' Tiempo restante=  856
# Valor= b'Euro' Tiempo restante=  848
# Valor= b'Euro' Tiempo restante=  844
# Valor= b'Euro' Tiempo restante=  840
# Valor= b'Euro' Tiempo restante=  836
# Valor= b'Euro' Tiempo restante=  829
# Valor= b'Euro' Tiempo restante=  824
# Valor= b'Euro' Tiempo restante=  820
# Valor= b'Euro' Tiempo restante=  812
# Valor= b'Euro' Tiempo restante=  808
# Valor= b'Euro' Tiempo restante=  804
# Valor= b'Euro' Tiempo restante=  798
# Valor= b'Euro' Tiempo restante=  793
# Valor= b'Euro' Tiempo restante=  790
# Valor= b'Euro' Tiempo restante=  786
# Valor= b'Euro' Tiempo restante=  781
# Valor= b'Euro' Tiempo restante=  777
# Valor= b'Euro' Tiempo restante=  774
# Valor= b'Euro' Tiempo restante=  771
# Valor= b'Euro' Tiempo restante=  765
# Valor= b'Euro' Tiempo restante=  761
# Valor= b'Euro' Tiempo restante=  757
# Valor= b'Euro' Tiempo restante=  754
# Valor= b'Euro' Tiempo restante=  748
# Valor= b'Euro' Tiempo restante=  744
# Valor= b'Euro' Tiempo restante=  741
# Valor= b'Euro' Tiempo restante=  737
# Valor= b'Euro' Tiempo restante=  732
# Valor= b'Euro' Tiempo restante=  727
# Valor= b'Euro' Tiempo restante=  724
# Valor= b'Euro' Tiempo restante=  721
# Valor= b'Euro' Tiempo restante=  710
# Valor= b'Euro' Tiempo restante=  707
# Valor= b'Euro' Tiempo restante=  703
# Valor= b'Euro' Tiempo restante=  698
# Valor= b'Euro' Tiempo restante=  694
# Valor= b'Euro' Tiempo restante=  691
# Valor= b'Euro' Tiempo restante=  688
# Valor= b'Euro' Tiempo restante=  683
# Valor= b'Euro' Tiempo restante=  678
# Valor= b'Euro' Tiempo restante=  674
# Valor= b'Euro' Tiempo restante=  671
# Valor= b'Euro' Tiempo restante=  665
# Valor= b'Euro' Tiempo restante=  661
# Valor= b'Euro' Tiempo restante=  656
# Valor= b'Euro' Tiempo restante=  652
# Valor= b'Euro' Tiempo restante=  646
# Valor= b'Euro' Tiempo restante=  642
# Valor= b'Euro' Tiempo restante=  638
# Valor= b'Euro' Tiempo restante=  632
# Valor= b'Euro' Tiempo restante=  627
# Valor= b'Euro' Tiempo restante=  623
# Valor= b'Euro' Tiempo restante=  620
# Valor= b'Euro' Tiempo restante=  612
# Valor= b'Euro' Tiempo restante=  607
# Valor= b'Euro' Tiempo restante=  604
# Valor= b'Euro' Tiempo restante=  596
# Valor= b'Euro' Tiempo restante=  592
# Valor= b'Euro' Tiempo restante=  588
# Valor= b'Euro' Tiempo restante=  582
# Valor= b'Euro' Tiempo restante=  576
# Valor= b'Euro' Tiempo restante=  572
# Valor= b'Euro' Tiempo restante=  567
# Valor= b'Euro' Tiempo restante=  563
# Valor= b'Euro' Tiempo restante=  559
# Valor= b'Euro' Tiempo restante=  555
# Valor= b'Euro' Tiempo restante=  549
# Valor= b'Euro' Tiempo restante=  544
# Valor= b'Euro' Tiempo restante=  541
# Valor= b'Euro' Tiempo restante=  538
# Valor= b'Euro' Tiempo restante=  531
# Valor= b'Euro' Tiempo restante=  527
# Valor= b'Euro' Tiempo restante=  524
# Valor= b'Euro' Tiempo restante=  517
# Valor= b'Euro' Tiempo restante=  510
# Valor= b'Euro' Tiempo restante=  505
# Valor= b'Euro' Tiempo restante=  500
# Valor= b'Euro' Tiempo restante=  494
# Valor= b'Euro' Tiempo restante=  491
# Valor= b'Euro' Tiempo restante=  487
# Valor= b'Euro' Tiempo restante=  481
# Valor= b'Euro' Tiempo restante=  477
# Valor= b'Euro' Tiempo restante=  474
# Valor= b'Euro' Tiempo restante=  466
# Valor= b'Euro' Tiempo restante=  461
# Valor= b'Euro' Tiempo restante=  457
# Valor= b'Euro' Tiempo restante=  450
# Valor= b'Euro' Tiempo restante=  446
# Valor= b'Euro' Tiempo restante=  442
# Valor= b'Euro' Tiempo restante=  437
# Valor= b'Euro' Tiempo restante=  431
# Valor= b'Euro' Tiempo restante=  427
# Valor= b'Euro' Tiempo restante=  424
# Valor= b'Euro' Tiempo restante=  420
# Valor= b'Euro' Tiempo restante=  413
# Valor= b'Euro' Tiempo restante=  410
# Valor= b'Euro' Tiempo restante=  407
# Valor= b'Euro' Tiempo restante=  404
# Valor= b'Euro' Tiempo restante=  399
# Valor= b'Euro' Tiempo restante=  394
# Valor= b'Euro' Tiempo restante=  391
# Valor= b'Euro' Tiempo restante=  386
# Valor= b'Euro' Tiempo restante=  380
# Valor= b'Euro' Tiempo restante=  376
# Valor= b'Euro' Tiempo restante=  373
# Valor= b'Euro' Tiempo restante=  370
# Valor= b'Euro' Tiempo restante=  364
# Valor= b'Euro' Tiempo restante=  361
# Valor= b'Euro' Tiempo restante=  358
# Valor= b'Euro' Tiempo restante=  354
# Valor= b'Euro' Tiempo restante=  350
# Valor= b'Euro' Tiempo restante=  346
# Valor= b'Euro' Tiempo restante=  342
# Valor= b'Euro' Tiempo restante=  339
# Valor= b'Euro' Tiempo restante=  336
# Valor= b'Euro' Tiempo restante=  328
# Valor= b'Euro' Tiempo restante=  325
# Valor= b'Euro' Tiempo restante=  322
# Valor= b'Euro' Tiempo restante=  318
# Valor= b'Euro' Tiempo restante=  312
# Valor= b'Euro' Tiempo restante=  309
# Valor= b'Euro' Tiempo restante=  306
# Valor= b'Euro' Tiempo restante=  299
# Valor= b'Euro' Tiempo restante=  295
# Valor= b'Euro' Tiempo restante=  293
# Valor= b'Euro' Tiempo restante=  290
# Valor= b'Euro' Tiempo restante=  285
# Valor= b'Euro' Tiempo restante=  280
# Valor= b'Euro' Tiempo restante=  276
# Valor= b'Euro' Tiempo restante=  272
# Valor= b'Euro' Tiempo restante=  267
# Valor= b'Euro' Tiempo restante=  263
# Valor= b'Euro' Tiempo restante=  259
# Valor= b'Euro' Tiempo restante=  255
# Valor= b'Euro' Tiempo restante=  249
# Valor= b'Euro' Tiempo restante=  246
# Valor= b'Euro' Tiempo restante=  243
# Valor= b'Euro' Tiempo restante=  239
# Valor= b'Euro' Tiempo restante=  232
# Valor= b'Euro' Tiempo restante=  226
# Valor= b'Euro' Tiempo restante=  222
# Valor= b'Euro' Tiempo restante=  217
# Valor= b'Euro' Tiempo restante=  212
# Valor= b'Euro' Tiempo restante=  209
# Valor= b'Euro' Tiempo restante=  205
# Valor= b'Euro' Tiempo restante=  200
# Valor= b'Euro' Tiempo restante=  196
# Valor= b'Euro' Tiempo restante=  193
# Valor= b'Euro' Tiempo restante=  190
# Valor= b'Euro' Tiempo restante=  187
# Valor= b'Euro' Tiempo restante=  183
# Valor= b'Euro' Tiempo restante=  179
# Valor= b'Euro' Tiempo restante=  176
# Valor= b'Euro' Tiempo restante=  172
# Valor= b'Euro' Tiempo restante=  167
# Valor= b'Euro' Tiempo restante=  163
# Valor= b'Euro' Tiempo restante=  160
# Valor= b'Euro' Tiempo restante=  157
# Valor= b'Euro' Tiempo restante=  154
# Valor= b'Euro' Tiempo restante=  149
# Valor= b'Euro' Tiempo restante=  144
# Valor= b'Euro' Tiempo restante=  141
# Valor= b'Euro' Tiempo restante=  138
# Valor= b'Euro' Tiempo restante=  133
# Valor= b'Euro' Tiempo restante=  128
# Valor= b'Euro' Tiempo restante=  124
# Valor= b'Euro' Tiempo restante=  121
# Valor= b'Euro' Tiempo restante=  115
# Valor= b'Euro' Tiempo restante=  112
# Valor= b'Euro' Tiempo restante=  109
# Valor= b'Euro' Tiempo restante=  106
# Valor= b'Euro' Tiempo restante=  101
# Valor= b'Euro' Tiempo restante=  97
# Valor= b'Euro' Tiempo restante=  94
# Valor= b'Euro' Tiempo restante=  91
# Valor= b'Euro' Tiempo restante=  88
# Valor= b'Euro' Tiempo restante=  82
# Valor= b'Euro' Tiempo restante=  79
# Valor= b'Euro' Tiempo restante=  75
# Valor= b'Euro' Tiempo restante=  72
# Valor= b'Euro' Tiempo restante=  67
# Valor= b'Euro' Tiempo restante=  63
# Valor= b'Euro' Tiempo restante=  59
# Valor= b'Euro' Tiempo restante=  55
# Valor= b'Euro' Tiempo restante=  49
# Valor= b'Euro' Tiempo restante=  45
# Valor= b'Euro' Tiempo restante=  43
# Valor= b'Euro' Tiempo restante=  40
# Valor= b'Euro' Tiempo restante=  33
# Valor= b'Euro' Tiempo restante=  29
# Valor= b'Euro' Tiempo restante=  25
# Valor= b'Euro' Tiempo restante=  22
# Valor= b'Euro' Tiempo restante=  16
# Valor= b'Euro' Tiempo restante=  12
# Valor= b'Euro' Tiempo restante=  9
# Valor= b'Euro' Tiempo restante=  5
# Valor= b'Euro' Tiempo restante=  1
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2
# Valor= None Tiempo restante=  -2

# %% [markdown]
# ## Ordenamiento

# %% [markdown]
# ### Ordenamiento Ejemplo 1

# %%
r.zadd('vehiculo', {'Auto' : 1})
r.zadd('vehiculo', {'Moto' : 2})
vehiculo = r.zrange('vehiculo', 0, -1, desc=False, withscores=True)
print(vehiculo)
# Out:
# [(b'Auto', 1.0), (b'Moto', 2.0)]

# %% [markdown]
# ### Ordenamiento Ejemplo 2

# %%
# Redis ordenamiento
judadores = 'Jugadores'
r.zadd(judadores, {'Ronaldo' : 100})
r.zadd(judadores, {'Messi' : 99})
r.zadd(judadores, {'Aguero' : 85})
r.zadd(judadores, {'Neymar' : 90})
r.zadd(judadores, {'Salah' : 89})

print("Cardinalidad:")
print(r.zcard(judadores))

print()
print("Cantidad de jugadores con rating entre 90-100:")
print(r.zcount(judadores, 90, 100))

print()
print("Cantidad de jugadores con rating entre 0-89:")
print(r.zcount(judadores, 0, 89))

print()
print("Buscar un valor:")
elementValue = "Messi"
print(f'Valor "{elementValue}" es {r.zscore(judadores, "Messi")}')

print()
print("Ordenamiento de valores:")
print(r.zrangebyscore(judadores, min=0, max=100, withscores = True))

print()
print("Ordenamiento de valores reverso:")
print(r.zrevrangebyscore(judadores, min=0, max=100, withscores = True))
# Out:
# Cardinalidad:
# 5
#
# Cantidad de jugadores con rating entre 90-100:
# 3
#
# Cantidad de jugadores con rating entre 0-89:
# 2
#
# Buscar un valor:
# Valor "Messi" es 99.0
#
# Ordenamiento de valores:
# [(b'Aguero', 85.0), (b'Salah', 89.0), (b'Neymar', 90.0), (b'Messi', 99.0), (b'Ronaldo', 100.0)]
#
# Ordenamiento de valores reverso:
# [(b'Ronaldo', 100.0), (b'Messi', 99.0), (b'Neymar', 90.0), (b'Salah', 89.0), (b'Aguero', 85.0)]

# %% [markdown]
# ### Ordenamiento Ejemplo 3

# %%
equipos = "Equipos"

r.zadd(equipos, {'Real Madrid': "1"})
r.zadd(equipos, {'Barcelona': "5"})
r.zadd(equipos, {'Juventus': "2"})
r.zadd(equipos, {'PSG': "3"})
r.zadd(equipos, {'Manchester United': "4"})
r.zadd(equipos, {'Milan': "5"})

print("Valores:")
print(r.zrange(equipos, 0, -1, desc=True, withscores=True))

print("Eliminar items:")
print(r.zrem(equipos, "Barcelona", "PSG"))

 
print("Eliminar items con valores:")
print(r.zremrangebyscore(equipos, 2, 5))

print("Visualizar items restantes:")
print(r.zrevrange(equipos, 0, -1, withscores=True))
# Out:
# Valores:
# [(b'Milan', 5.0), (b'Barcelona', 5.0), (b'Manchester United', 4.0), (b'PSG', 3.0), (b'Juventus', 2.0), (b'Real Madrid', 1.0)]
# Eliminar items:
# 2
# Eliminar items con valores:
# 3
# Visualizar items restantes:
# [(b'Real Madrid', 1.0)]
